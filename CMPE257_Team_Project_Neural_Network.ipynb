# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns
import re
from itertools import product
import os
import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('data/sales_train.csv')
test = pd.read_csv('data/test.csv')
shops = pd.read_csv('data/shops.csv')
cats = pd.read_csv('data/item_categories.csv')
items = pd.read_csv('data/items.csv')

# %%
len(train.item_id.unique())
# Out:
# 21807

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# 1. Remove Outliers

# %%
plt.figure(figsize=(10,4))
plt.xlim(-100, 3000)
flierprops = dict(marker='o', markerfacecolor='purple', markersize=6,
                  linestyle='none', markeredgecolor='black')
sns.boxplot(x=train.item_cnt_day, flierprops=flierprops)

plt.figure(figsize=(10,4))
plt.xlim(train.item_price.min(), train.item_price.max()*1.1)
sns.boxplot(x=train.item_price, flierprops=flierprops)
# Out:
# <AxesSubplot:xlabel='item_price'>

# %%
train = train[(train.item_price < 300000 ) & (train.item_cnt_day < 1000)]

# %%
# remove negative price and sales count
train = train[train.item_price > 0].reset_index(drop = True)
train.loc[train.item_cnt_day < 1, "item_cnt_day"] = 0

# %% [markdown]
# 2. Cleaning Shop Data
#
# Several of the shops look like duplicates of each other. This could be down to shops re-opening or possibly moving store location on the same street or shopping centre.

# %%
# Якутск Орджоникидзе, 56
train.loc[train.shop_id == 0, 'shop_id'] = 57
test.loc[test.shop_id == 0, 'shop_id'] = 57
# Якутск ТЦ "Центральный"
train.loc[train.shop_id == 1, 'shop_id'] = 58
test.loc[test.shop_id == 1, 'shop_id'] = 58
# Жуковский ул. Чкалова 39м²
train.loc[train.shop_id == 10, 'shop_id'] = 11
test.loc[test.shop_id == 10, 'shop_id'] = 11

# %%
# Clean up some shop names and add 'city' and 'category' to shops df.

shops.loc[ shops.shop_name == 'Сергиев Посад ТЦ "7Я"',"shop_name" ] = 'СергиевПосад ТЦ "7Я"'
shops["city"] = shops.shop_name.str.split(" ").map( lambda x: x[0] )
shops["category"] = shops.shop_name.str.split(" ").map( lambda x: x[1] )
shops.loc[shops.city == "!Якутск", "city"] = "Якутск"
shops.head()
# Out:
#                         shop_name  shop_id      city       category
# 0   !Якутск Орджоникидзе, 56 фран        0    Якутск  Орджоникидзе,
# 1   !Якутск ТЦ "Центральный" фран        1    Якутск             ТЦ
# 2                Адыгея ТЦ "Мега"        2    Адыгея             ТЦ
# 3  Балашиха ТРК "Октябрь-Киномир"        3  Балашиха            ТРК
# 4        Волжский ТЦ "Волга Молл"        4  Волжский             ТЦ

# %%
# Only keep shop category if there are 5 or more shops of that category, the rest are grouped as "other".
category = []
for cat in shops.category.unique():
    if len(shops[shops.category == cat]) >= 5:
        category.append(cat)
shops.category = shops.category.apply( lambda x: x if (x in category) else "other" )
shops.head()
# Out:
#                         shop_name  shop_id      city category
# 0   !Якутск Орджоникидзе, 56 фран        0    Якутск    other
# 1   !Якутск ТЦ "Центральный" фран        1    Якутск       ТЦ
# 2                Адыгея ТЦ "Мега"        2    Адыгея       ТЦ
# 3  Балашиха ТРК "Октябрь-Киномир"        3  Балашиха      ТРК
# 4        Волжский ТЦ "Волга Молл"        4  Волжский       ТЦ

# %%
# encode shop category and city using labelencoder
shops["shop_category"] = LabelEncoder().fit_transform( shops.category )
shops["shop_city"] = LabelEncoder().fit_transform( shops.city )
shops = shops[["shop_id", "shop_category", "shop_city"]]
shops
# Out:
#     shop_id  shop_category  shop_city
# 0         0              0         29
# 1         1              4         29
# 2         2              4          0
# 3         3              2          1
# 4         4              4          2
# 5         5              3          3
# 6         6              0          4
# 7         7              3          4
# 8         8              3          4
# 9         9              0          5
# 10       10              0          6
# 11       11              0          6
# 12       12              0          7
# 13       13              4          8
# 14       14              4          8
# 15       15              3          9
# 16       16              4         10
# 17       17              4         11
# 18       18              4         11
# 19       19              4         12
# 20       20              0         13
# 21       21              0         13
# 22       22              0         13
# 23       23              1         13
# 24       24              1         13
# 25       25              2         13
# 26       26              4         13
# 27       27              4         13
# 28       28              4         13
# 29       29              4         13
# 30       30              4         13
# 31       31              4         13
# 32       32              4         13
# 33       33              2         14
# 34       34              3         15
# 35       35              3         15
# 36       36              3         16
# 37       37              4         16
# 38       38              4         17
# 39       39              2         18
# 40       40              2         18
# 41       41              4         18
# 42       42              1         19
# 43       43              1         19
# 44       44              4         20
# 45       45              4         20
# 46       46              4         21
# 47       47              3         22
# 48       48              3         23
# 49       49              3         24
# 50       50              4         24
# 51       51              4         24
# 52       52              1         25
# 53       53              4         25
# 54       54              4         26
# 55       55              0         27
# 56       56              3         28
# 57       57              0         29
# 58       58              4         29
# 59       59              4         30

# %% [markdown]
# 3. Cleaning Item Category Data

# %%
# split the category name and extract category type
cats["type_code"] = cats.item_category_name.apply( lambda x: x.split(" ")[0] ).astype(str)
cats.loc[ (cats.type_code == "Игровые")| (cats.type_code == "Аксессуары"), "category" ] = "Игры"
cats.head()
# Out:
#         item_category_name  item_category_id   type_code category
# 0  PC - Гарнитуры/Наушники                 0          PC      NaN
# 1         Аксессуары - PS2                 1  Аксессуары     Игры
# 2         Аксессуары - PS3                 2  Аксессуары     Игры
# 3         Аксессуары - PS4                 3  Аксессуары     Игры
# 4         Аксессуары - PSP                 4  Аксессуары     Игры

# %%
# If a category type has >=5 categories, make it a type otherwise make it etc
category = []
for cat in cats.type_code.unique():
    if len(cats[cats.type_code == cat]) >= 5: 
        category.append( cat )
cats.type_code = cats.type_code.apply(lambda x: x if (x in category) else "etc")
cats
# Out:
#            item_category_name  item_category_id   type_code category
# 0     PC - Гарнитуры/Наушники                 0         etc      NaN
# 1            Аксессуары - PS2                 1  Аксессуары     Игры
# 2            Аксессуары - PS3                 2  Аксессуары     Игры
# 3            Аксессуары - PS4                 3  Аксессуары     Игры
# 4            Аксессуары - PSP                 4  Аксессуары     Игры
# ..                        ...               ...         ...      ...
# 79                  Служебные                79         etc      NaN
# 80         Служебные - Билеты                80         etc      NaN
# 81    Чистые носители (шпиль)                81         etc      NaN
# 82  Чистые носители (штучные)                82         etc      NaN
# 83           Элементы питания                83         etc      NaN
#
# [84 rows x 4 columns]

# %%
# encode type_code using label encoder
cats.type_code = LabelEncoder().fit_transform(cats.type_code)

# extract subtype from category name and encode it
cats["split"] = cats.item_category_name.apply(lambda x: x.split("-"))
cats["subtype"] = cats.split.apply(lambda x: x[1].strip() if len(x) > 1 else x[0].strip())
cats["subtype_code"] = LabelEncoder().fit_transform( cats["subtype"] )
cats = cats[["item_category_id", "subtype_code", "type_code"]]
cats
# Out:
#     item_category_id  subtype_code  type_code
# 0                  0            29          0
# 1                  1             9          1
# 2                  2            10          1
# 3                  3            11          1
# 4                  4            13          1
# ..               ...           ...        ...
# 79                79            54          0
# 80                80            25          0
# 81                81            62          0
# 82                82            63          0
# 83                83            64          0
#
# [84 rows x 3 columns]

# %% [markdown]
# 4. Cleaning Item Data

# %%
def name_correction(x):
    x = x.lower() # all letters lower case
    x = x.partition('[')[0] # partition by square brackets
    x = x.partition('(')[0] # partition by curly brackets
    x = re.sub('[^A-Za-z0-9А-Яа-я]+', ' ', x) # remove special characters
    x = x.replace('  ', ' ') # replace double spaces with single spaces
    x = x.strip() # remove leading and trailing white space
    return x

# %%
# Clean item names.

# split item names by first bracket
items["name1"], items["name2"] = items.item_name.str.split("[", 1).str
items["name1"], items["name3"] = items.item_name.str.split("(", 1).str

# replace special characters and turn to lower case
items["name2"] = items.name2.str.replace('[^A-Za-z0-9А-Яа-я]+', " ").str.lower()
items["name3"] = items.name3.str.replace('[^A-Za-z0-9А-Яа-я]+', " ").str.lower()

# fill nulls with '0'
items = items.fillna('0')

items["item_name"] = items["item_name"].apply(lambda x: name_correction(x))

# return all characters except the last if name 2 is not "0" - remove the closing bracket
items.name2 = items.name2.apply( lambda x: x[:-1] if x !="0" else "0")

# %%
items.head(20)
# Out:
#                                         item_name  item_id  item_category_id  \
# 0                            во власти наваждения        0                40
# 1   abbyy finereader 12 professional edition full        1                76
# 2                                   в лучах славы        2                40
# 3                                   голубая волна        3                40
# 4                                         коробка        4                40
# 5                     новые американские граффити        5                40
# 6                                 удар по воротам        6                40
# 7                               удар по воротам 2        7                40
# 8                               чай с муссолини d        8                40
# 9                          шугарлэндский экспресс        9                40
# 10                             за гранью смерти d       10                40
# 11                                 линия смерти d       11                40
# 12                  михей и джуманджи сука любовь       12                55
# 13                                 спасая эмили d       13                40
# 14                     чокнутый профессор магия d       14                40
# 15                     адреналин один против всех       15                40
# 16                                монгол с бодров       16                40
# 17                           не оставляющий следа       17                40
# 18                       бомба для невесты 2dvd d       18                40
# 19                       золотая коллекция м ф 72       19                40
#
#                                                 name1               name2  \
# 0                             ! ВО ВЛАСТИ НАВАЖДЕНИЯ                    0
# 1   !ABBYY FineReader 12 Professional Edition Full...  pc цифровая версия
# 2                                 ***В ЛУЧАХ СЛАВЫ                      0
# 3                                  ***ГОЛУБАЯ ВОЛНА                     0
# 4                                         ***КОРОБКА                    0
# 5                    ***НОВЫЕ АМЕРИКАНСКИЕ ГРАФФИТИ                     0
# 6                                 ***УДАР ПО ВОРОТАМ                    0
# 7                               ***УДАР ПО ВОРОТАМ-2                    0
# 8            ***ЧАЙ С МУССОЛИНИ                     D                   0
# 9                          ***ШУГАРЛЭНДСКИЙ ЭКСПРЕСС                    0
# 10          *ЗА ГРАНЬЮ СМЕРТИ                       D                   0
# 11          *ЛИНИЯ СМЕРТИ                           D                   0
# 12                    *МИХЕЙ И ДЖУМАНДЖИ  Сука любовь                   0
# 13          *СПАСАЯ ЭМИЛИ                           D                   0
# 14          *ЧОКНУТЫЙ ПРОФЕССОР /МАГИЯ/             D                   0
# 15                     //АДРЕНАЛИН: ОДИН ПРОТИВ ВСЕХ                    0
# 16                                 //МОНГОЛ С.Бодров                    0
# 17                            //НЕ ОСТАВЛЯЮЩИЙ СЛЕДА                    0
# 18          /БОМБА ДЛЯ НЕВЕСТЫ /2DVD/               D                   0
# 19                          /ЗОЛОТАЯ КОЛЛЕКЦИЯ м/ф-72                   0
#
#        name3
# 0    пласт d
# 1          0
# 2      unv d
# 3     univ d
# 4   стекло d
# 5      uni d
# 6      uni d
# 7      uni d
# 8          0
# 9      uni d
# 10         0
# 11         0
# 12         0
# 13         0
# 14         0
# 15   регион
# 16   регион
# 17   регион
# 18         0
# 19         0

# %%
# Clean item type (type populated based on name2)

items["type"] = items.name2.apply(lambda x: x[0:8] if x.split(" ")[0] == "xbox" else x.split(" ")[0] )
items.loc[(items.type == "x360") | (items.type == "xbox360") | (items.type == "xbox 360") ,"type"] = "xbox 360"
items.loc[ items.type == "", "type"] = "mac"
items.type = items.type.apply( lambda x: x.replace(" ", "") )
items.loc[ (items.type == 'pc' )| (items.type == 'pс') | (items.type == "pc"), "type" ] = "pc"
items.loc[ items.type == 'рs3' , "type"] = "ps3"

items.head(20)
# Out:
#                                         item_name  item_id  item_category_id  \
# 0                            во власти наваждения        0                40
# 1   abbyy finereader 12 professional edition full        1                76
# 2                                   в лучах славы        2                40
# 3                                   голубая волна        3                40
# 4                                         коробка        4                40
# 5                     новые американские граффити        5                40
# 6                                 удар по воротам        6                40
# 7                               удар по воротам 2        7                40
# 8                               чай с муссолини d        8                40
# 9                          шугарлэндский экспресс        9                40
# 10                             за гранью смерти d       10                40
# 11                                 линия смерти d       11                40
# 12                  михей и джуманджи сука любовь       12                55
# 13                                 спасая эмили d       13                40
# 14                     чокнутый профессор магия d       14                40
# 15                     адреналин один против всех       15                40
# 16                                монгол с бодров       16                40
# 17                           не оставляющий следа       17                40
# 18                       бомба для невесты 2dvd d       18                40
# 19                       золотая коллекция м ф 72       19                40
#
#                                                 name1               name2  \
# 0                             ! ВО ВЛАСТИ НАВАЖДЕНИЯ                    0
# 1   !ABBYY FineReader 12 Professional Edition Full...  pc цифровая версия
# 2                                 ***В ЛУЧАХ СЛАВЫ                      0
# 3                                  ***ГОЛУБАЯ ВОЛНА                     0
# 4                                         ***КОРОБКА                    0
# 5                    ***НОВЫЕ АМЕРИКАНСКИЕ ГРАФФИТИ                     0
# 6                                 ***УДАР ПО ВОРОТАМ                    0
# 7                               ***УДАР ПО ВОРОТАМ-2                    0
# 8            ***ЧАЙ С МУССОЛИНИ                     D                   0
# 9                          ***ШУГАРЛЭНДСКИЙ ЭКСПРЕСС                    0
# 10          *ЗА ГРАНЬЮ СМЕРТИ                       D                   0
# 11          *ЛИНИЯ СМЕРТИ                           D                   0
# 12                    *МИХЕЙ И ДЖУМАНДЖИ  Сука любовь                   0
# 13          *СПАСАЯ ЭМИЛИ                           D                   0
# 14          *ЧОКНУТЫЙ ПРОФЕССОР /МАГИЯ/             D                   0
# 15                     //АДРЕНАЛИН: ОДИН ПРОТИВ ВСЕХ                    0
# 16                                 //МОНГОЛ С.Бодров                    0
# 17                            //НЕ ОСТАВЛЯЮЩИЙ СЛЕДА                    0
# 18          /БОМБА ДЛЯ НЕВЕСТЫ /2DVD/               D                   0
# 19                          /ЗОЛОТАЯ КОЛЛЕКЦИЯ м/ф-72                   0
#
#        name3 type
# 0    пласт d    0
# 1          0   pc
# 2      unv d    0
# 3     univ d    0
# 4   стекло d    0
# 5      uni d    0
# 6      uni d    0
# 7      uni d    0
# 8          0    0
# 9      uni d    0
# 10         0    0
# 11         0    0
# 12         0    0
# 13         0    0
# 14         0    0
# 15   регион     0
# 16   регион     0
# 17   регион     0
# 18         0    0
# 19         0    0

# %%
# how many items in each item type
group_sum = items.groupby(["type"]).agg({"item_id": "count"})
group_sum = group_sum.reset_index()
group_sum
# Out:
#         type  item_id
# 0          0    17661
# 1        5c5        1
# 2        5c7        2
# 3        5f4        1
# 4        6dv        1
# 5        6jv        1
# 6        6l6        1
# 7    android        3
# 8        hm3        1
# 9        j72        4
# 10       kf6        1
# 11       kf7        1
# 12       kg4        1
# 13       mac       43
# 14        pc     2628
# 15        ps       79
# 16       ps2        2
# 17       ps3      611
# 18       ps4      174
# 19       psp      115
# 20       s3v        1
# 21       s4v        1
# 22   xbox360      466
# 23   xboxone      123
# 24      англ        1
# 25        рс       14
# 26   русская        1
# 27    только        9
# 28     цифро        1
# 29  цифровая      222

# %%
# if a type has less than 40 items, make them into one single type called other
drop_cols = []
for cat in group_sum.type.unique():
    if group_sum.loc[(group_sum.type == cat), "item_id"].values[0] <40:
        drop_cols.append(cat)

items.name2 = items.name2.apply( lambda x: "other" if (x in drop_cols) else x )
items = items.drop(["type"], axis = 1)

# %%
# encode name2 and name3 
items.name2 = LabelEncoder().fit_transform(items.name2)
items.name3 = LabelEncoder().fit_transform(items.name3)

items.drop(["item_name", "name1"],axis = 1, inplace= True)
items.head()
# Out:
#    item_id  item_category_id  name2  name3
# 0        0                40      4   1331
# 1        1                76     64     42
# 2        2                40      4   1011
# 3        3                40      4   1010
# 4        4                40      4   1572

# %% [markdown]
# # Preprocessing

# %%
train.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00           0.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
#if an item sles less than 10 in 34 months, then drop the item for further training
item_head = train.groupby('item_id')['item_cnt_day'].sum()
item_head.shape
# Out:
# (21806,)

# %%
item_head = item_head.loc[item_head.values > 10]
item_head
# Out:
# item_id
# 27         42.0
# 28         85.0
# 29         13.0
# 30       2090.0
# 31       1440.0
#           ...
# 22162     700.0
# 22163      75.0
# 22164     494.0
# 22166     348.0
# 22167    1321.0
# Name: item_cnt_day, Length: 15110, dtype: float64

# %%
shop_ids = list(set(train.shop_id)|set(test.shop_id))
item_ids = list(set(item_head.index)|set(test.item_id))
print(len(shop_ids))
print(len(item_ids))
# Out:
# 57
# 15999

# %%
# Create a matrix df with every combination of month, shop and item.
months = range(34)
cols  = ["date_block_num", "shop_id", "item_id"]
matrix_ = list(product(months, shop_ids, item_ids )) 
len(matrix_)
# Out:
# 31006062

# %%
matrix = pd.DataFrame(data = matrix_, columns = cols )
matrix["date_block_num"] = matrix["date_block_num"].astype(np.int8)
matrix["shop_id"] = matrix["shop_id"].astype(np.int8)
matrix["item_id"] = matrix["item_id"].astype(np.int16)
matrix.sort_values( cols, inplace = True )
matrix
# Out:
#           date_block_num  shop_id  item_id
# 0                      0        2       27
# 1                      0        2       28
# 2                      0        2       29
# 3                      0        2       30
# 4                      0        2       31
# ...                  ...      ...      ...
# 31006057              33       59    22162
# 31006058              33       59    22163
# 31006059              33       59    22164
# 31006060              33       59    22166
# 31006061              33       59    22167
#
# [31006062 rows x 3 columns]

# %%
# add revenue to train df
train["revenue"] = train["item_cnt_day"] * train["item_price"]
train
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935840  10.10.2015              33       25     7409      299.00
# 2935841  09.10.2015              33       25     7460      299.00
# 2935842  14.10.2015              33       25     7459      349.00
# 2935843  22.10.2015              33       25     7440      299.00
# 2935844  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day  revenue
# 0                 1.0   999.00
# 1                 1.0   899.00
# 2                 0.0     0.00
# 3                 1.0  1709.05
# 4                 1.0  1099.00
# ...               ...      ...
# 2935840           1.0   299.00
# 2935841           1.0   299.00
# 2935842           1.0   349.00
# 2935843           1.0   299.00
# 2935844           1.0   299.00
#
# [2935845 rows x 7 columns]

# %%
# get monthly item count
group = train.groupby( ["date_block_num", "shop_id", "item_id"] ).agg( {"item_cnt_day": ["sum"], "revenue":"sum"} )
group.columns = ["item_cnt_month", "revenue_month"]
group.reset_index( inplace = True)
group
# Out:
#          date_block_num  shop_id  item_id  item_cnt_month  revenue_month
# 0                     0        2       27             1.0         2499.0
# 1                     0        2       33             1.0          499.0
# 2                     0        2      317             1.0          299.0
# 3                     0        2      438             1.0          299.0
# 4                     0        2      471             2.0          798.0
# ...                 ...      ...      ...             ...            ...
# 1609117              33       59    22087             6.0          714.0
# 1609118              33       59    22088             2.0          238.0
# 1609119              33       59    22091             1.0          179.0
# 1609120              33       59    22100             1.0          629.0
# 1609121              33       59    22102             1.0         1250.0
#
# [1609122 rows x 5 columns]

# %%
# add monthly item count to matrix
matrix = pd.merge( matrix, group, on = cols, how = "left" )

# %%
matrix = matrix.fillna(0)
matrix
# Out:
#           date_block_num  shop_id  item_id  item_cnt_month  revenue_month
# 0                      0        2       27             1.0         2499.0
# 1                      0        2       28             0.0            0.0
# 2                      0        2       29             0.0            0.0
# 3                      0        2       30             0.0            0.0
# 4                      0        2       31             0.0            0.0
# ...                  ...      ...      ...             ...            ...
# 31006057              33       59    22162             0.0            0.0
# 31006058              33       59    22163             0.0            0.0
# 31006059              33       59    22164             0.0            0.0
# 31006060              33       59    22166             0.0            0.0
# 31006061              33       59    22167             0.0            0.0
#
# [31006062 rows x 5 columns]

# %%
# Add shop, items and categories data onto matrix df.
matrix = pd.merge( matrix, shops, on = ["shop_id"], how = "left" )
matrix = pd.merge(matrix, items, on = ["item_id"], how = "left")
matrix = pd.merge( matrix, cats, on = ["item_category_id"], how = "left" )
matrix["shop_city"] = matrix["shop_city"].astype(np.int8)
matrix["shop_category"] = matrix["shop_category"].astype(np.int8)
matrix["item_category_id"] = matrix["item_category_id"].astype(np.int8)
matrix["subtype_code"] = matrix["subtype_code"].astype(np.int8)
matrix["name2"] = matrix["name2"].astype(np.int8)
matrix["name3"] = matrix["name3"].astype(np.int16)
matrix["type_code"] = matrix["type_code"].astype(np.int8)
matrix
# Out:
#           date_block_num  shop_id  item_id  item_cnt_month  revenue_month  \
# 0                      0        2       27             1.0         2499.0
# 1                      0        2       28             0.0            0.0
# 2                      0        2       29             0.0            0.0
# 3                      0        2       30             0.0            0.0
# 4                      0        2       31             0.0            0.0
# ...                  ...      ...      ...             ...            ...
# 31006057              33       59    22162             0.0            0.0
# 31006058              33       59    22163             0.0            0.0
# 31006059              33       59    22164             0.0            0.0
# 31006060              33       59    22166             0.0            0.0
# 31006061              33       59    22167             0.0            0.0
#
#           shop_category  shop_city  item_category_id  name2  name3  \
# 0                     4          0                19     76     42
# 1                     4          0                30    107     42
# 2                     4          0                23    123     42
# 3                     4          0                40      4     42
# 4                     4          0                37      4    562
# ...                 ...        ...               ...    ...    ...
# 31006057              4         30                40      4     42
# 31006058              4         30                40      4     36
# 31006059              4         30                37      4    562
# 31006060              4         30                54    -85     42
# 31006061              4         30                49      4     19
#
#           subtype_code  type_code
# 0                   10          3
# 1                   55          3
# 2                   16          3
# 3                    4          5
# 4                    1          5
# ...                ...        ...
# 31006057             4          5
# 31006058             4          5
# 31006059             1          5
# 31006060            61          6
# 31006061            39          6
#
# [31006062 rows x 12 columns]

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# Add additional features related to item count

# %%
def add_feature(df, group_by, col, col_name):
  group = df.groupby( group_by ).agg({col : ["mean"]})
  group.columns = [col_name]
  group.reset_index(inplace = True)
  df = pd.merge(df, group, on = group_by, how = "left")
  df[col_name] = df[col_name].astype(np.float16)
  return df

# %%
# average item count per month-shop-item_cat 
matrix = add_feature(matrix, ['date_block_num', 'shop_id', 'item_category_id'], "item_cnt_month", "month_shop_itemcat_avg_cnt")

# %%
# average item count per month-shop-item_type
matrix = add_feature(matrix, ['date_block_num', 'shop_id', 'type_code'], "item_cnt_month", "month_shop_itemtype_avg_cnt")

# %%
# average item count per month-city-item
matrix = add_feature(matrix, ['date_block_num', 'shop_city', 'item_id'], "item_cnt_month", "month_city_item_avg_cnt")

# %%
# average item count per month-city-item_cat
matrix = add_feature(matrix, ['date_block_num', 'shop_city', 'item_category_id'], "item_cnt_month", "month_city_itemcat_avg_cnt")

# %%
# average item count per month-shop
matrix = add_feature(matrix, ['date_block_num', 'shop_id'], "item_cnt_month", "month_shop_avg_cnt")

# %%
# average item count per month-shop_cat
matrix = add_feature(matrix, ['date_block_num', 'shop_category'], "item_cnt_month", "month_shopcat_avg_cnt")

# %%
# average item count per month-item
matrix = add_feature(matrix, ['date_block_num', 'item_id'], "item_cnt_month", "month_item_avg_cnt")

# %%
# average item count per month-item_cat
matrix = add_feature(matrix, ['date_block_num', 'item_category_id'], "item_cnt_month", "month_itemcat_avg_cnt")

# %%
# average item count per month-city
matrix = add_feature(matrix, ['date_block_num', 'shop_city'], "item_cnt_month", "month_city_avg_cnt")

# %%
# average item count per month
matrix = add_feature(matrix, ['date_block_num'], "item_cnt_month", "month_avg_cnt")

# %%
# average item count per item
matrix = add_feature(matrix, ['item_id'], "item_cnt_month", "item_avg_cnt")

# %%
# average item count per shop
matrix = add_feature(matrix, ['shop_id'], "item_cnt_month", "shop_avg_cnt")

# %% [markdown]
# Add additional features related to date to capture cycle and seasonality

# %%
# month
matrix['month'] = matrix['date_block_num']%12
matrix
# Out:
#           date_block_num  shop_id  item_id  item_cnt_month  revenue_month  \
# 0                      0        2       27             1.0         2499.0
# 1                      0        2       28             0.0            0.0
# 2                      0        2       29             0.0            0.0
# 3                      0        2       30             0.0            0.0
# 4                      0        2       31             0.0            0.0
# ...                  ...      ...      ...             ...            ...
# 31006057              33       59    22162             0.0            0.0
# 31006058              33       59    22163             0.0            0.0
# 31006059              33       59    22164             0.0            0.0
# 31006060              33       59    22166             0.0            0.0
# 31006061              33       59    22167             0.0            0.0
#
#           shop_category  shop_city  item_category_id  name2  name3  ...  \
# 0                     4          0                19     76     42  ...
# 1                     4          0                30    107     42  ...
# 2                     4          0                23    123     42  ...
# 3                     4          0                40      4     42  ...
# 4                     4          0                37      4    562  ...
# ...                 ...        ...               ...    ...    ...  ...
# 31006057              4         30                40      4     42  ...
# 31006058              4         30                40      4     36  ...
# 31006059              4         30                37      4    562  ...
# 31006060              4         30                54    -85     42  ...
# 31006061              4         30                49      4     19  ...
#
#           month_city_itemcat_avg_cnt  month_shop_avg_cnt  \
# 0                           0.237549            0.070312
# 1                           0.440918            0.070312
# 2                           0.090881            0.070312
# 3                           0.040771            0.070312
# 4                           0.034729            0.070312
# ...                              ...                 ...
# 31006057                    0.019653            0.049500
# 31006058                    0.019653            0.049500
# 31006059                    0.042236            0.049500
# 31006060                    0.000000            0.049500
# 31006061                    0.006943            0.049500
#
#           month_shopcat_avg_cnt  month_item_avg_cnt  month_itemcat_avg_cnt  \
# 0                      0.188354            0.122803               0.326660
# 1                      0.188354            0.140381               0.775391
# 2                      0.188354            0.087708               0.190674
# 3                      0.188354            0.000000               0.141968
# 4                      0.188354            0.000000               0.071533
# ...                         ...                 ...                    ...
# 31006057               0.061127            0.175415               0.033020
# 31006058               0.061127            0.456055               0.033020
# 31006059               0.061127            0.263184               0.048584
# 31006060               0.061127            0.192993               0.095947
# 31006061               0.061127            0.648926               0.077881
#
#           month_city_avg_cnt  month_avg_cnt  item_avg_cnt  shop_avg_cnt  month
# 0                   0.070312       0.141968      0.021667      0.056244      0
# 1                   0.070312       0.141968      0.043854      0.056244      0
# 2                   0.070312       0.141968      0.006706      0.056244      0
# 3                   0.070312       0.141968      1.078125      0.056244      0
# 4                   0.070312       0.141968      0.743164      0.056244      0
# ...                      ...            ...           ...           ...    ...
# 31006057            0.049500       0.074951      0.361084      0.090088      9
# 31006058            0.049500       0.074951      0.038696      0.090088      9
# 31006059            0.049500       0.074951      0.254883      0.090088      9
# 31006060            0.049500       0.074951      0.179565      0.090088      9
# 31006061            0.049500       0.074951      0.681641      0.090088      9
#
# [31006062 rows x 25 columns]

# %%
# year
import math
matrix['year'] = matrix['date_block_num']/12
matrix['year'] = matrix.year.apply(lambda x: math.floor(x))
matrix
# Out:
#           date_block_num  shop_id  item_id  item_cnt_month  revenue_month  \
# 0                      0        2       27             1.0         2499.0
# 1                      0        2       28             0.0            0.0
# 2                      0        2       29             0.0            0.0
# 3                      0        2       30             0.0            0.0
# 4                      0        2       31             0.0            0.0
# ...                  ...      ...      ...             ...            ...
# 31006057              33       59    22162             0.0            0.0
# 31006058              33       59    22163             0.0            0.0
# 31006059              33       59    22164             0.0            0.0
# 31006060              33       59    22166             0.0            0.0
# 31006061              33       59    22167             0.0            0.0
#
#           shop_category  shop_city  item_category_id  name2  name3  ...  \
# 0                     4          0                19     76     42  ...
# 1                     4          0                30    107     42  ...
# 2                     4          0                23    123     42  ...
# 3                     4          0                40      4     42  ...
# 4                     4          0                37      4    562  ...
# ...                 ...        ...               ...    ...    ...  ...
# 31006057              4         30                40      4     42  ...
# 31006058              4         30                40      4     36  ...
# 31006059              4         30                37      4    562  ...
# 31006060              4         30                54    -85     42  ...
# 31006061              4         30                49      4     19  ...
#
#           month_shop_avg_cnt  month_shopcat_avg_cnt  month_item_avg_cnt  \
# 0                   0.070312               0.188354            0.122803
# 1                   0.070312               0.188354            0.140381
# 2                   0.070312               0.188354            0.087708
# 3                   0.070312               0.188354            0.000000
# 4                   0.070312               0.188354            0.000000
# ...                      ...                    ...                 ...
# 31006057            0.049500               0.061127            0.175415
# 31006058            0.049500               0.061127            0.456055
# 31006059            0.049500               0.061127            0.263184
# 31006060            0.049500               0.061127            0.192993
# 31006061            0.049500               0.061127            0.648926
#
#           month_itemcat_avg_cnt  month_city_avg_cnt  month_avg_cnt  \
# 0                      0.326660            0.070312       0.141968
# 1                      0.775391            0.070312       0.141968
# 2                      0.190674            0.070312       0.141968
# 3                      0.141968            0.070312       0.141968
# 4                      0.071533            0.070312       0.141968
# ...                         ...                 ...            ...
# 31006057               0.033020            0.049500       0.074951
# 31006058               0.033020            0.049500       0.074951
# 31006059               0.048584            0.049500       0.074951
# 31006060               0.095947            0.049500       0.074951
# 31006061               0.077881            0.049500       0.074951
#
#           item_avg_cnt  shop_avg_cnt  month  year
# 0             0.021667      0.056244      0     0
# 1             0.043854      0.056244      0     0
# 2             0.006706      0.056244      0     0
# 3             1.078125      0.056244      0     0
# 4             0.743164      0.056244      0     0
# ...                ...           ...    ...   ...
# 31006057      0.361084      0.090088      9     2
# 31006058      0.038696      0.090088      9     2
# 31006059      0.254883      0.090088      9     2
# 31006060      0.179565      0.090088      9     2
# 31006061      0.681641      0.090088      9     2
#
# [31006062 rows x 26 columns]

# %%
# season 
season = pd.Series([0,0,0,1,1,1,2,2,2,3,3,3])
matrix["season"] = matrix["month"].map(season).astype(np.int8)

# %%
# number of days in the month
days = pd.Series([31,28,31,30,31,30,31,31,30,31,30,31])
matrix["days"] = matrix["month"].map(days).astype(np.int8)

# %% [markdown]
# Add additional features related to price

# %%
# avg price per month-item
group = train.groupby( ['date_block_num', 'item_id'] ).agg({"item_price" : ["mean"]})
group.columns = ["month_avg_item_price"]
group.reset_index(inplace = True)
matrix = pd.merge(matrix, group, on = ['date_block_num', 'item_id'], how = "left")
matrix
# Out:
#           date_block_num  shop_id  item_id  item_cnt_month  revenue_month  \
# 0                      0        2       27             1.0         2499.0
# 1                      0        2       28             0.0            0.0
# 2                      0        2       29             0.0            0.0
# 3                      0        2       30             0.0            0.0
# 4                      0        2       31             0.0            0.0
# ...                  ...      ...      ...             ...            ...
# 31006057              33       59    22162             0.0            0.0
# 31006058              33       59    22163             0.0            0.0
# 31006059              33       59    22164             0.0            0.0
# 31006060              33       59    22166             0.0            0.0
# 31006061              33       59    22167             0.0            0.0
#
#           shop_category  shop_city  item_category_id  name2  name3  ...  \
# 0                     4          0                19     76     42  ...
# 1                     4          0                30    107     42  ...
# 2                     4          0                23    123     42  ...
# 3                     4          0                40      4     42  ...
# 4                     4          0                37      4    562  ...
# ...                 ...        ...               ...    ...    ...  ...
# 31006057              4         30                40      4     42  ...
# 31006058              4         30                40      4     36  ...
# 31006059              4         30                37      4    562  ...
# 31006060              4         30                54    -85     42  ...
# 31006061              4         30                49      4     19  ...
#
#           month_itemcat_avg_cnt  month_city_avg_cnt  month_avg_cnt  \
# 0                      0.326660            0.070312       0.141968
# 1                      0.775391            0.070312       0.141968
# 2                      0.190674            0.070312       0.141968
# 3                      0.141968            0.070312       0.141968
# 4                      0.071533            0.070312       0.141968
# ...                         ...                 ...            ...
# 31006057               0.033020            0.049500       0.074951
# 31006058               0.033020            0.049500       0.074951
# 31006059               0.048584            0.049500       0.074951
# 31006060               0.095947            0.049500       0.074951
# 31006061               0.077881            0.049500       0.074951
#
#           item_avg_cnt  shop_avg_cnt  month  year  season  days  \
# 0             0.021667      0.056244      0     0       0    31
# 1             0.043854      0.056244      0     0       0    31
# 2             0.006706      0.056244      0     0       0    31
# 3             1.078125      0.056244      0     0       0    31
# 4             0.743164      0.056244      0     0       0    31
# ...                ...           ...    ...   ...     ...   ...
# 31006057      0.361084      0.090088      9     2       3    31
# 31006058      0.038696      0.090088      9     2       3    31
# 31006059      0.254883      0.090088      9     2       3    31
# 31006060      0.179565      0.090088      9     2       3    31
# 31006061      0.681641      0.090088      9     2       3    31
#
#           month_avg_item_price
# 0                  2325.000000
# 1                   549.000000
# 2                  2397.500000
# 3                          NaN
# 4                          NaN
# ...                        ...
# 31006057            349.000000
# 31006058            162.698400
# 31006059            549.000000
# 31006060            150.000000
# 31006061            293.098437
#
# [31006062 rows x 29 columns]

# %%
# avg price per year-item
year_price = train[['date', 'item_id','item_price']]
year_price['year'] = year_price.apply(lambda row: int(row.date.split('.')[2])-2013, axis = 1)
year_price
# Out:
#                date  item_id  item_price  year
# 0        02.01.2013    22154      999.00     0
# 1        03.01.2013     2552      899.00     0
# 2        05.01.2013     2552      899.00     0
# 3        06.01.2013     2554     1709.05     0
# 4        15.01.2013     2555     1099.00     0
# ...             ...      ...         ...   ...
# 2935840  10.10.2015     7409      299.00     2
# 2935841  09.10.2015     7460      299.00     2
# 2935842  14.10.2015     7459      349.00     2
# 2935843  22.10.2015     7440      299.00     2
# 2935844  03.10.2015     7460      299.00     2
#
# [2935845 rows x 4 columns]

# %%
group = year_price.groupby( ['year', 'item_id'] ).agg({"item_price" : ["mean"]})
group.columns = ["year_avg_item_price"]
group.reset_index(inplace = True)
matrix = pd.merge(matrix, group, on = ['year', 'item_id'], how = "left")
matrix["year_avg_item_price"] = matrix['year_avg_item_price'].astype(np.float16)
matrix
# Out:
#           date_block_num  shop_id  item_id  item_cnt_month  revenue_month  \
# 0                      0        2       27             1.0         2499.0
# 1                      0        2       28             0.0            0.0
# 2                      0        2       29             0.0            0.0
# 3                      0        2       30             0.0            0.0
# 4                      0        2       31             0.0            0.0
# ...                  ...      ...      ...             ...            ...
# 31006057              33       59    22162             0.0            0.0
# 31006058              33       59    22163             0.0            0.0
# 31006059              33       59    22164             0.0            0.0
# 31006060              33       59    22166             0.0            0.0
# 31006061              33       59    22167             0.0            0.0
#
#           shop_category  shop_city  item_category_id  name2  name3  ...  \
# 0                     4          0                19     76     42  ...
# 1                     4          0                30    107     42  ...
# 2                     4          0                23    123     42  ...
# 3                     4          0                40      4     42  ...
# 4                     4          0                37      4    562  ...
# ...                 ...        ...               ...    ...    ...  ...
# 31006057              4         30                40      4     42  ...
# 31006058              4         30                40      4     36  ...
# 31006059              4         30                37      4    562  ...
# 31006060              4         30                54    -85     42  ...
# 31006061              4         30                49      4     19  ...
#
#           month_city_avg_cnt  month_avg_cnt  item_avg_cnt  shop_avg_cnt  \
# 0                   0.070312       0.141968      0.021667      0.056244
# 1                   0.070312       0.141968      0.043854      0.056244
# 2                   0.070312       0.141968      0.006706      0.056244
# 3                   0.070312       0.141968      1.078125      0.056244
# 4                   0.070312       0.141968      0.743164      0.056244
# ...                      ...            ...           ...           ...
# 31006057            0.049500       0.074951      0.361084      0.090088
# 31006058            0.049500       0.074951      0.038696      0.090088
# 31006059            0.049500       0.074951      0.254883      0.090088
# 31006060            0.049500       0.074951      0.179565      0.090088
# 31006061            0.049500       0.074951      0.681641      0.090088
#
#           month  year  season  days  month_avg_item_price  year_avg_item_price
# 0             0     0       0    31           2325.000000             1594.000
# 1             0     0       0    31            549.000000              311.250
# 2             0     0       0    31           2397.500000             1802.000
# 3             0     0       0    31                   NaN              366.500
# 4             0     0       0    31                   NaN              662.500
# ...         ...   ...     ...   ...                   ...                  ...
# 31006057      9     2       3    31            349.000000              382.250
# 31006058      9     2       3    31            162.698400              164.625
# 31006059      9     2       3    31            549.000000              713.500
# 31006060      9     2       3    31            150.000000              150.000
# 31006061      9     2       3    31            293.098437              298.000
#
# [31006062 rows x 30 columns]

# %%
year_cat_price = pd.merge(year_price,items[['item_id','item_category_id']], on = 'item_id', how = 'left')

# %%
year_cat_price = year_cat_price[['item_price', 'year', 'item_category_id']].groupby( ['year', 'item_category_id'] ).agg({"item_price" : ["mean"]})
year_cat_price.columns = year_cat_price.columns.droplevel()
year_cat_price = year_cat_price.reset_index()
year_cat_price.columns = ['year', 'item_category_id', 'year_avg_cat_price']

# %%
matrix = pd.merge(matrix, year_cat_price, on = ['year','item_category_id'], how = 'left')

# %%
# avg item price
group = train.groupby( ["item_id"] ).agg({"item_price": ["mean"]})
group.columns = ["item_avg_item_price"]
group.reset_index(inplace = True)
matrix = pd.merge( matrix,group, on = ["item_id"], how = "left" )
matrix["item_avg_item_price"] = matrix['item_avg_item_price'].astype(np.float16)

# %% [markdown]
# Delta features

# %%
#Lag features for change in price values
def lag_feature( df,lags, cols ):
    for col in cols:
        print(col)
        tmp = df[["date_block_num", "shop_id","item_id",col ]]
        for i in lags:
            shifted = tmp.copy()
            shifted.columns = ["date_block_num", "shop_id", "item_id", col + "_lag_"+str(i)]
            shifted.date_block_num = shifted.date_block_num + i
            df = pd.merge(df, shifted, on=['date_block_num','shop_id','item_id'], how='left')
    return df

# %%
lags = [1, 2, 3]
matrix = lag_feature( matrix, lags, ["month_avg_item_price"] )
# Out:
# month_avg_item_price

# %%
for i in lags:
    matrix["delta_price_lag_" + str(i) ] = (matrix["month_avg_item_price_lag_" + str(i)]- matrix["item_avg_item_price"] )/ matrix["item_avg_item_price"]

# %%
#Function to select just one change in price compared to the rest 3
def select_trends(row) :
    for i in lags:
        if row["delta_price_lag_" + str(i)]:
            return row["delta_price_lag_" + str(i)]
    return 0

# %%
matrix["delta_price_lag"] = matrix.apply(select_trends, axis = 1)
matrix["delta_price_lag"] = matrix['delta_price_lag'].astype( np.float16 )
matrix["delta_price_lag"].fillna( 0 ,inplace = True)

# %%
#Drop unwanted features 
features_to_drop = ["item_avg_item_price", "month_avg_item_price"]
for i in lags:
    features_to_drop.append("month_avg_item_price_lag_" + str(i) )
    features_to_drop.append("delta_price_lag_" + str(i) )
matrix.drop(features_to_drop, axis = 1, inplace = True)

# %%
#Lag features for item_cnt_month
lags = [1, 2, 3, 4, 5, 6]
matrix = lag_feature( matrix, lags, ["item_cnt_month"] )
matrix
# Out:
# item_cnt_month
#           date_block_num  shop_id  item_id  item_cnt_month  revenue_month  \
# 0                      0        2       27             1.0         2499.0
# 1                      0        2       28             0.0            0.0
# 2                      0        2       29             0.0            0.0
# 3                      0        2       30             0.0            0.0
# 4                      0        2       31             0.0            0.0
# ...                  ...      ...      ...             ...            ...
# 31006057              33       59    22162             0.0            0.0
# 31006058              33       59    22163             0.0            0.0
# 31006059              33       59    22164             0.0            0.0
# 31006060              33       59    22166             0.0            0.0
# 31006061              33       59    22167             0.0            0.0
#
#           shop_category  shop_city  item_category_id  name2  name3  ...  days  \
# 0                     4          0                19     76     42  ...    31
# 1                     4          0                30    107     42  ...    31
# 2                     4          0                23    123     42  ...    31
# 3                     4          0                40      4     42  ...    31
# 4                     4          0                37      4    562  ...    31
# ...                 ...        ...               ...    ...    ...  ...   ...
# 31006057              4         30                40      4     42  ...    31
# 31006058              4         30                40      4     36  ...    31
# 31006059              4         30                37      4    562  ...    31
# 31006060              4         30                54    -85     42  ...    31
# 31006061              4         30                49      4     19  ...    31
#
#           year_avg_item_price  year_avg_cat_price  delta_price_lag  \
# 0                    1594.000         1514.601304         0.000000
# 1                     311.250          456.299900         0.000000
# 2                    1802.000         1543.248943         0.000000
# 3                     366.500          248.578945         0.000000
# 4                     662.500          442.218438         0.000000
# ...                       ...                 ...              ...
# 31006057              382.250          271.537594        -0.085815
# 31006058              164.625          271.537594         0.026581
# 31006059              713.500          451.071719        -0.230591
# 31006060              150.000          192.252784         0.000000
# 31006061              298.000          438.455974         0.004200
#
#           item_cnt_month_lag_1  item_cnt_month_lag_2  item_cnt_month_lag_3  \
# 0                          NaN                   NaN                   NaN
# 1                          NaN                   NaN                   NaN
# 2                          NaN                   NaN                   NaN
# 3                          NaN                   NaN                   NaN
# 4                          NaN                   NaN                   NaN
# ...                        ...                   ...                   ...
# 31006057                   0.0                   1.0                   0.0
# 31006058                   0.0                   0.0                   0.0
# 31006059                   0.0                   0.0                   1.0
# 31006060                   0.0                   0.0                   0.0
# 31006061                   0.0                   0.0                   0.0
#
#           item_cnt_month_lag_4  item_cnt_month_lag_5  item_cnt_month_lag_6
# 0                          NaN                   NaN                   NaN
# 1                          NaN                   NaN                   NaN
# 2                          NaN                   NaN                   NaN
# 3                          NaN                   NaN                   NaN
# 4                          NaN                   NaN                   NaN
# ...                        ...                   ...                   ...
# 31006057                   0.0                   1.0                   1.0
# 31006058                   0.0                   0.0                   0.0
# 31006059                   0.0                   0.0                   2.0
# 31006060                   0.0                   0.0                   0.0
# 31006061                   0.0                   0.0                   0.0
#
# [31006062 rows x 37 columns]

# %% [markdown]
# Other features trend, first sales, last sell shops,…

# %%
#Revenue for shops based on date
group = train.groupby( ["date_block_num","shop_id"] ).agg({"revenue": ["sum"] })
group.columns = ["date_shop_revenue"]
group.reset_index(inplace = True)
matrix = matrix.merge( group , on = ["date_block_num", "shop_id"], how = "left" )
matrix['date_shop_revenue'] = matrix['date_shop_revenue'].astype(np.float32)

# %%
# Shop avg revenue
group = group.groupby(["shop_id"]).agg({ "date_block_num":["mean"] })
group.columns = ["shop_avg_revenue"]
group.reset_index(inplace = True )
matrix = matrix.merge( group, on = ["shop_id"], how = "left" )
matrix["shop_avg_revenue"] = matrix.shop_avg_revenue.astype(np.float32)

# %%
#Change in revenue - how current month revenue changes to global average
matrix["delta_revenue"] = (matrix['date_shop_revenue'] - matrix['shop_avg_revenue']) / matrix['shop_avg_revenue']
matrix["delta_revenue"] = matrix["delta_revenue"]. astype(np.float32)

# %%
matrix = lag_feature(matrix, [1], ["delta_revenue"])
matrix["delta_revenue_lag_1"] = matrix["delta_revenue_lag_1"].astype(np.float32)
# Out:
# delta_revenue

# %%
#Remove unwanted features after calculating the delta 
matrix.drop( ["date_shop_revenue", "shop_avg_revenue", "delta_revenue"] ,axis = 1, inplace = True)

# %%
#Item first sold in shop
matrix["item_shop_first_sale"] = matrix["date_block_num"] - matrix.groupby(["item_id","shop_id"])["date_block_num"].transform('min')
#Item first sold globally
matrix["item_first_sale"] = matrix["date_block_num"] - matrix.groupby(["item_id"])["date_block_num"].transform('min')

# %%
#Removing first 6 months as they dont have lag values
matrix = matrix[matrix["date_block_num"] > 5]

# %%
matrix
# Out:
#           date_block_num  shop_id  item_id  item_cnt_month  revenue_month  \
# 5471658                6        2       27             0.0            0.0
# 5471659                6        2       28             0.0            0.0
# 5471660                6        2       29             0.0            0.0
# 5471661                6        2       30             0.0            0.0
# 5471662                6        2       31             0.0            0.0
# ...                  ...      ...      ...             ...            ...
# 31006057              33       59    22162             0.0            0.0
# 31006058              33       59    22163             0.0            0.0
# 31006059              33       59    22164             0.0            0.0
# 31006060              33       59    22166             0.0            0.0
# 31006061              33       59    22167             0.0            0.0
#
#           shop_category  shop_city  item_category_id  name2  name3  ...  \
# 5471658               4          0                19     76     42  ...
# 5471659               4          0                30    107     42  ...
# 5471660               4          0                23    123     42  ...
# 5471661               4          0                40      4     42  ...
# 5471662               4          0                37      4    562  ...
# ...                 ...        ...               ...    ...    ...  ...
# 31006057              4         30                40      4     42  ...
# 31006058              4         30                40      4     36  ...
# 31006059              4         30                37      4    562  ...
# 31006060              4         30                54    -85     42  ...
# 31006061              4         30                49      4     19  ...
#
#           delta_price_lag  item_cnt_month_lag_1  item_cnt_month_lag_2  \
# 5471658         -0.043121                   0.0                   0.0
# 5471659         -0.038696                   0.0                   0.0
# 5471660          0.000000                   0.0                   0.0
# 5471661          0.232422                   1.0                   0.0
# 5471662          0.208252                   0.0                   0.0
# ...                   ...                   ...                   ...
# 31006057        -0.085815                   0.0                   1.0
# 31006058         0.026581                   0.0                   0.0
# 31006059        -0.230591                   0.0                   0.0
# 31006060         0.000000                   0.0                   0.0
# 31006061         0.004200                   0.0                   0.0
#
#           item_cnt_month_lag_3  item_cnt_month_lag_4  item_cnt_month_lag_5  \
# 5471658                    0.0                   0.0                   0.0
# 5471659                    0.0                   0.0                   0.0
# 5471660                    0.0                   0.0                   0.0
# 5471661                    0.0                   1.0                   0.0
# 5471662                    1.0                   1.0                   4.0
# ...                        ...                   ...                   ...
# 31006057                   0.0                   0.0                   1.0
# 31006058                   0.0                   0.0                   0.0
# 31006059                   1.0                   0.0                   0.0
# 31006060                   0.0                   0.0                   0.0
# 31006061                   0.0                   0.0                   0.0
#
#           item_cnt_month_lag_6  delta_revenue_lag_1  item_shop_first_sale  \
# 5471658                    1.0         50141.062500                     6
# 5471659                    0.0         50141.062500                     6
# 5471660                    0.0         50141.062500                     6
# 5471661                    0.0         50141.062500                     6
# 5471662                    0.0         50141.062500                     6
# ...                        ...                  ...                   ...
# 31006057                   1.0         66717.367188                    33
# 31006058                   0.0         66717.367188                    33
# 31006059                   2.0         66717.367188                    33
# 31006060                   0.0         66717.367188                    33
# 31006061                   0.0         66717.367188                    33
#
#           item_first_sale
# 5471658                 6
# 5471659                 6
# 5471660                 6
# 5471661                 6
# 5471662                 6
# ...                   ...
# 31006057               33
# 31006058               33
# 31006059               33
# 31006060               33
# 31006061               33
#
# [25534404 rows x 40 columns]

# %% [markdown]
# Adding the number of Russian holidays per month as a feature

# %%
holidays_in_month = [7, 1, 2, 1, 6, 2, 0, 0, 0, 0, 1, 1]
holidays_next_month = [1, 2, 1, 6, 2, 0, 0, 0, 0, 1, 1, 7]
test_holidays = matrix.copy()

# %%
test_holidays["holidays_in_month"] = 0
test_holidays["holidays_next_month"] = 0

for i in range(0, 12):
    test_holidays['holidays_in_month'] = np.where(test_holidays['date_block_num']%12 == i, holidays_in_month[i], test_holidays['holidays_in_month'])

for i in range(0, 12):
    test_holidays['holidays_next_month'] = np.where(test_holidays['date_block_num']%12 == i, holidays_next_month[i], test_holidays['holidays_next_month'])

matrix = test_holidays
del test_holidays
matrix
# Out:
#           date_block_num  shop_id  item_id  item_cnt_month  revenue_month  \
# 5471658                6        2       27             0.0            0.0
# 5471659                6        2       28             0.0            0.0
# 5471660                6        2       29             0.0            0.0
# 5471661                6        2       30             0.0            0.0
# 5471662                6        2       31             0.0            0.0
# ...                  ...      ...      ...             ...            ...
# 31006057              33       59    22162             0.0            0.0
# 31006058              33       59    22163             0.0            0.0
# 31006059              33       59    22164             0.0            0.0
# 31006060              33       59    22166             0.0            0.0
# 31006061              33       59    22167             0.0            0.0
#
#           shop_category  shop_city  item_category_id  name2  name3  ...  \
# 5471658               4          0                19     76     42  ...
# 5471659               4          0                30    107     42  ...
# 5471660               4          0                23    123     42  ...
# 5471661               4          0                40      4     42  ...
# 5471662               4          0                37      4    562  ...
# ...                 ...        ...               ...    ...    ...  ...
# 31006057              4         30                40      4     42  ...
# 31006058              4         30                40      4     36  ...
# 31006059              4         30                37      4    562  ...
# 31006060              4         30                54    -85     42  ...
# 31006061              4         30                49      4     19  ...
#
#           item_cnt_month_lag_2  item_cnt_month_lag_3  item_cnt_month_lag_4  \
# 5471658                    0.0                   0.0                   0.0
# 5471659                    0.0                   0.0                   0.0
# 5471660                    0.0                   0.0                   0.0
# 5471661                    0.0                   0.0                   1.0
# 5471662                    0.0                   1.0                   1.0
# ...                        ...                   ...                   ...
# 31006057                   1.0                   0.0                   0.0
# 31006058                   0.0                   0.0                   0.0
# 31006059                   0.0                   1.0                   0.0
# 31006060                   0.0                   0.0                   0.0
# 31006061                   0.0                   0.0                   0.0
#
#           item_cnt_month_lag_5  item_cnt_month_lag_6  delta_revenue_lag_1  \
# 5471658                    0.0                   1.0         50141.062500
# 5471659                    0.0                   0.0         50141.062500
# 5471660                    0.0                   0.0         50141.062500
# 5471661                    0.0                   0.0         50141.062500
# 5471662                    4.0                   0.0         50141.062500
# ...                        ...                   ...                  ...
# 31006057                   1.0                   1.0         66717.367188
# 31006058                   0.0                   0.0         66717.367188
# 31006059                   0.0                   2.0         66717.367188
# 31006060                   0.0                   0.0         66717.367188
# 31006061                   0.0                   0.0         66717.367188
#
#           item_shop_first_sale  item_first_sale  holidays_in_month  \
# 5471658                      6                6                  0
# 5471659                      6                6                  0
# 5471660                      6                6                  0
# 5471661                      6                6                  0
# 5471662                      6                6                  0
# ...                        ...              ...                ...
# 31006057                    33               33                  0
# 31006058                    33               33                  0
# 31006059                    33               33                  0
# 31006060                    33               33                  0
# 31006061                    33               33                  0
#
#           holidays_next_month
# 5471658                     0
# 5471659                     0
# 5471660                     0
# 5471661                     0
# 5471662                     0
# ...                       ...
# 31006057                    1
# 31006058                    1
# 31006059                    1
# 31006060                    1
# 31006061                    1
#
# [25534404 rows x 42 columns]

# %%
#Generate label columns
data = matrix.fillna(0).copy()
right_df = data[['date_block_num', 'shop_id', 'item_id', 'item_cnt_month']]
right_df['pre_block'] = right_df['date_block_num'] -1
data = pd.merge(data, right_df, how = 'left', left_on = ['date_block_num', 'shop_id', 'item_id'], right_on= ['pre_block', 'shop_id', 'item_id'])
data.rename(columns = {'date_block_num_x':'date_block_num', 'item_cnt_month_x':'item_cnt_this_month', 'item_cnt_month_y':'item_cnt_next_month'}, inplace=True)

# %%
data.drop(columns = ['date_block_num_y', 'pre_block'], inplace = True)
data.fillna(0, inplace=True)

# %%
data
# Out:
#           date_block_num  shop_id  item_id  item_cnt_this_month  \
# 0                      6        2       27                  0.0
# 1                      6        2       28                  0.0
# 2                      6        2       29                  0.0
# 3                      6        2       30                  0.0
# 4                      6        2       31                  0.0
# ...                  ...      ...      ...                  ...
# 25534399              33       59    22162                  0.0
# 25534400              33       59    22163                  0.0
# 25534401              33       59    22164                  0.0
# 25534402              33       59    22166                  0.0
# 25534403              33       59    22167                  0.0
#
#           revenue_month  shop_category  shop_city  item_category_id  name2  \
# 0                   0.0              4          0                19     76
# 1                   0.0              4          0                30    107
# 2                   0.0              4          0                23    123
# 3                   0.0              4          0                40      4
# 4                   0.0              4          0                37      4
# ...                 ...            ...        ...               ...    ...
# 25534399            0.0              4         30                40      4
# 25534400            0.0              4         30                40      4
# 25534401            0.0              4         30                37      4
# 25534402            0.0              4         30                54    -85
# 25534403            0.0              4         30                49      4
#
#           name3  ...  item_cnt_month_lag_3  item_cnt_month_lag_4  \
# 0            42  ...                   0.0                   0.0
# 1            42  ...                   0.0                   0.0
# 2            42  ...                   0.0                   0.0
# 3            42  ...                   0.0                   1.0
# 4           562  ...                   1.0                   1.0
# ...         ...  ...                   ...                   ...
# 25534399     42  ...                   0.0                   0.0
# 25534400     36  ...                   0.0                   0.0
# 25534401    562  ...                   1.0                   0.0
# 25534402     42  ...                   0.0                   0.0
# 25534403     19  ...                   0.0                   0.0
#
#           item_cnt_month_lag_5  item_cnt_month_lag_6  delta_revenue_lag_1  \
# 0                          0.0                   1.0         50141.062500
# 1                          0.0                   0.0         50141.062500
# 2                          0.0                   0.0         50141.062500
# 3                          0.0                   0.0         50141.062500
# 4                          4.0                   0.0         50141.062500
# ...                        ...                   ...                  ...
# 25534399                   1.0                   1.0         66717.367188
# 25534400                   0.0                   0.0         66717.367188
# 25534401                   0.0                   2.0         66717.367188
# 25534402                   0.0                   0.0         66717.367188
# 25534403                   0.0                   0.0         66717.367188
#
#           item_shop_first_sale  item_first_sale  holidays_in_month  \
# 0                            6                6                  0
# 1                            6                6                  0
# 2                            6                6                  0
# 3                            6                6                  0
# 4                            6                6                  0
# ...                        ...              ...                ...
# 25534399                    33               33                  0
# 25534400                    33               33                  0
# 25534401                    33               33                  0
# 25534402                    33               33                  0
# 25534403                    33               33                  0
#
#           holidays_next_month  item_cnt_next_month
# 0                           0                  0.0
# 1                           0                  0.0
# 2                           0                  0.0
# 3                           0                  0.0
# 4                           0                  0.0
# ...                       ...                  ...
# 25534399                    1                  0.0
# 25534400                    1                  0.0
# 25534401                    1                  0.0
# 25534402                    1                  0.0
# 25534403                    1                  0.0
#
# [25534404 rows x 43 columns]

# %%
data
# Out:
#           date_block_num  shop_id  item_id  item_cnt_this_month  \
# 0                      6        2       27                  0.0
# 1                      6        2       28                  0.0
# 2                      6        2       29                  0.0
# 3                      6        2       30                  0.0
# 4                      6        2       31                  0.0
# ...                  ...      ...      ...                  ...
# 25534399              33       59    22162                  0.0
# 25534400              33       59    22163                  0.0
# 25534401              33       59    22164                  0.0
# 25534402              33       59    22166                  0.0
# 25534403              33       59    22167                  0.0
#
#           revenue_month  shop_category  shop_city  item_category_id  name2  \
# 0                   0.0              4          0                19     76
# 1                   0.0              4          0                30    107
# 2                   0.0              4          0                23    123
# 3                   0.0              4          0                40      4
# 4                   0.0              4          0                37      4
# ...                 ...            ...        ...               ...    ...
# 25534399            0.0              4         30                40      4
# 25534400            0.0              4         30                40      4
# 25534401            0.0              4         30                37      4
# 25534402            0.0              4         30                54    -85
# 25534403            0.0              4         30                49      4
#
#           name3  ...  item_cnt_month_lag_3  item_cnt_month_lag_4  \
# 0            42  ...                   0.0                   0.0
# 1            42  ...                   0.0                   0.0
# 2            42  ...                   0.0                   0.0
# 3            42  ...                   0.0                   1.0
# 4           562  ...                   1.0                   1.0
# ...         ...  ...                   ...                   ...
# 25534399     42  ...                   0.0                   0.0
# 25534400     36  ...                   0.0                   0.0
# 25534401    562  ...                   1.0                   0.0
# 25534402     42  ...                   0.0                   0.0
# 25534403     19  ...                   0.0                   0.0
#
#           item_cnt_month_lag_5  item_cnt_month_lag_6  delta_revenue_lag_1  \
# 0                          0.0                   1.0         50141.062500
# 1                          0.0                   0.0         50141.062500
# 2                          0.0                   0.0         50141.062500
# 3                          0.0                   0.0         50141.062500
# 4                          4.0                   0.0         50141.062500
# ...                        ...                   ...                  ...
# 25534399                   1.0                   1.0         66717.367188
# 25534400                   0.0                   0.0         66717.367188
# 25534401                   0.0                   2.0         66717.367188
# 25534402                   0.0                   0.0         66717.367188
# 25534403                   0.0                   0.0         66717.367188
#
#           item_shop_first_sale  item_first_sale  holidays_in_month  \
# 0                            6                6                  0
# 1                            6                6                  0
# 2                            6                6                  0
# 3                            6                6                  0
# 4                            6                6                  0
# ...                        ...              ...                ...
# 25534399                    33               33                  0
# 25534400                    33               33                  0
# 25534401                    33               33                  0
# 25534402                    33               33                  0
# 25534403                    33               33                  0
#
#           holidays_next_month  item_cnt_next_month
# 0                           0                  0.0
# 1                           0                  0.0
# 2                           0                  0.0
# 3                           0                  0.0
# 4                           0                  0.0
# ...                       ...                  ...
# 25534399                    1                  0.0
# 25534400                    1                  0.0
# 25534401                    1                  0.0
# 25534402                    1                  0.0
# 25534403                    1                  0.0
#
# [25534404 rows x 43 columns]

# %%
data.columns
# Out:
# Index(['date_block_num', 'shop_id', 'item_id', 'item_cnt_this_month',
#        'revenue_month', 'shop_category', 'shop_city', 'item_category_id',
#        'name2', 'name3', 'subtype_code', 'type_code',
#        'month_shop_itemcat_avg_cnt', 'month_shop_itemtype_avg_cnt',
#        'month_city_item_avg_cnt', 'month_city_itemcat_avg_cnt',
#        'month_shop_avg_cnt', 'month_shopcat_avg_cnt', 'month_item_avg_cnt',
#        'month_itemcat_avg_cnt', 'month_city_avg_cnt', 'month_avg_cnt',
#        'item_avg_cnt', 'shop_avg_cnt', 'month', 'year', 'season', 'days',
#        'year_avg_item_price', 'year_avg_cat_price', 'delta_price_lag',
#        'item_cnt_month_lag_1', 'item_cnt_month_lag_2', 'item_cnt_month_lag_3',
#        'item_cnt_month_lag_4', 'item_cnt_month_lag_5', 'item_cnt_month_lag_6',
#        'delta_revenue_lag_1', 'item_shop_first_sale', 'item_first_sale',
#        'holidays_in_month', 'holidays_next_month', 'item_cnt_next_month'],
#       dtype='object')

# %%
select_features = ['revenue_month', 'shop_category', 'shop_city', 'item_category_id',
    'subtype_code', 'type_code', 'month', 'year',
    'season', 'days', 'delta_price_lag', 'item_cnt_month_lag_1',
    'item_cnt_month_lag_2', 'item_cnt_month_lag_3', 'delta_revenue_lag_1',
    'item_shop_first_sale', 'item_first_sale', 'holidays_in_month']

train = data.loc[data.date_block_num < 32]
valid = data.loc[data.date_block_num == 32]
testx = data.loc[data.date_block_num == 33]

X_train = train[select_features]
y_train = train.item_cnt_next_month
X_valid = valid[select_features]
y_valid = valid.item_cnt_next_month
X_testx = testx[select_features]
print(X_train.shape)
print(X_valid.shape)
print(X_testx.shape)
# Out:
# (23710518, 18)
# (911943, 18)
# (911943, 18)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
scaler = StandardScaler()
scaler.fit(X_train)
X_train_standarized=scaler.transform(X_train)
X_valid_standarized=scaler.transform(X_valid)
X_testx_standarized=scaler.transform(X_testx)

# %%
pca = PCA(n_components=16, svd_solver='full')
pca.fit(X_train_standarized)
# Out:
# PCA(n_components=16, svd_solver='full')

# %%
print(pca.explained_variance_ratio_.sum())
# Out:
# 0.9999999999999999

# %%
X_train_pca = pca.transform(X_train_standarized)
X_valid_pca = pca.transform(X_valid_standarized)
X_testx_pca = pca.transform(X_testx_standarized)

# %%
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.pipeline import Pipeline
from keras import callbacks

earlystopping = callbacks.EarlyStopping(monitor ="val_loss", 
                                        mode ="min", patience = 10, 
                                        restore_best_weights = True)

# %%
from sklearn.metrics import mean_squared_error
def rmse(model, X_valid, y_valid = y_valid):
    y_pred = model.predict(X_valid)
    rmse = mean_squared_error(y_valid, y_pred, squared = False)
    print(rmse)

# %%
def save_submission(test_pred, file_name, test = test):
    submission = pd.merge(test, test_pred, how = 'left', on = ['shop_id', 'item_id'] ) 
    submission.fillna(0, inplace=True)
    submission.loc[: , ['ID', 'item_cnt_month']].to_csv(file_name, index = None)

# %%
def pred_n_save(model, file_name, test = test, X_test = X_testx):
    index = X_test.index
    test_pred = model.predict(X_test)
    test_pred = pd.DataFrame(data = test_pred, index = index, columns = ['item_cnt_month'])
    test_pred
    pred = pd.concat([testx.loc[:, ['shop_id', 'item_id']], test_pred], axis = 1)
    pred.loc[pred['item_cnt_month'] < 0, 'item_cnt_month'] = 0
    submission = pd.merge(test, pred, how = 'left', on = ['shop_id', 'item_id'] ) 
    submission.fillna(0, inplace=True)
    submission.loc[: , ['ID', 'item_cnt_month']].to_csv(file_name, index = None)

# %%
def base_model():
    # create model
    model = Sequential()
    model.add(Dense(20, input_dim=X_train.shape[1], kernel_initializer='normal', activation='relu'))
    model.add(Dense(12, activation='relu'))
    model.add(Dense(1, activation='linear'))
    # Compile model
    model.compile(loss='mean_squared_error', optimizer='adam', metrics = 'mse')
    return model

# %%
def base_model_pca():
    # create model
    model = Sequential()
    model.add(Dense(20, input_dim=X_train_pca.shape[1], kernel_initializer='normal', activation='relu'))
    model.add(Dense(12, activation='relu'))
    model.add(Dense(1, activation='linear'))
    # Compile model
    model.compile(loss='mean_squared_error', optimizer='adam', metrics = 'mse')
    return model

# %%
def wider_model():
    # create model
    model = Sequential()
    model.add(Dense(40, input_dim=X_train.shape[1], kernel_initializer='normal', activation='relu'))
    model.add(Dense(60, activation='relu'))
    model.add(Dense(1, activation='linear'))
    # Compile model
    model.compile(loss='mean_squared_error', optimizer='adam', metrics = 'mse')
    return model

# %%
def wider_model_pca():
    # create model
    model = Sequential()
    model.add(Dense(40, input_dim=X_train_pca.shape[1], kernel_initializer='normal', activation='relu'))
    model.add(Dense(60, activation='relu'))
    model.add(Dense(1, activation='linear'))
    # Compile model
    model.compile(loss='mean_squared_error', optimizer='adam', metrics = 'mse')
    return model

# %%
def deeper_model():
    # create model
    model = Sequential()
    model.add(Dense(40, input_dim=X_train.shape[1], kernel_initializer='normal', activation='relu'))
    model.add(Dense(60, activation='relu'))
    model.add(Dense(60, activation='relu'))
    model.add(Dense(12, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation='linear'))
    # Compile mode
    model.compile(loss='mean_squared_error', optimizer='adam', metrics = 'mse')
    return model

# %%
#Use basic model
model_1 = base_model()
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 20)                380
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                252
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 13
# =================================================================
# Total params: 645
# Trainable params: 645
# Non-trainable params: 0
# _________________________________________________________________

# %%
history1 = model_1.fit(X_train, y_train, validation_data = (X_valid, y_valid), batch_size = 5000, epochs=30, callbacks = [earlystopping])
# Out:
# Epoch 1/30
# 4743/4743 [==============================] - 8s 1ms/step - loss: 6302.5948 - mse: 6302.5948 - val_loss: 75.7437 - val_mse: 75.7437
# Epoch 2/30
# 4743/4743 [==============================] - 5s 1ms/step - loss: 206.4168 - mse: 206.4168 - val_loss: 164.4052 - val_mse: 164.4052
# Epoch 3/30
# 4743/4743 [==============================] - 5s 1ms/step - loss: 105.5948 - mse: 105.5948 - val_loss: 11.7075 - val_mse: 11.7075
# Epoch 4/30
# 4743/4743 [==============================] - 6s 1ms/step - loss: 134.7169 - mse: 134.7169 - val_loss: 12.3159 - val_mse: 12.3159
# Epoch 5/30
# 4743/4743 [==============================] - 5s 1ms/step - loss: 101.8320 - mse: 101.8320 - val_loss: 15.5778 - val_mse: 15.5778
# Epoch 6/30
# 4743/4743 [==============================] - 5s 1ms/step - loss: 132.0457 - mse: 132.0457 - val_loss: 1.6005 - val_mse: 1.6005
# Epoch 7/30
# 4743/4743 [==============================] - 5s 1ms/step - loss: 64.0539 - mse: 64.0539 - val_loss: 1.5225 - val_mse: 1.5225
# Epoch 8/30
# 4743/4743 [==============================] - 6s 1ms/step - loss: 50.5817 - mse: 50.5817 - val_loss: 1.1575 - val_mse: 1.1575
# Epoch 9/30
# 4743/4743 [==============================] - 5s 1ms/step - loss: 75.2537 - mse: 75.2537 - val_loss: 2.0182 - val_mse: 2.0182
# Epoch 10/30
# 4743/4743 [==============================] - 5s 1ms/step - loss: 18.2532 - mse: 18.2532 - val_loss: 1.2216 - val_mse: 1.2216
# Epoch 11/30
# 4743/4743 [==============================] - 5s 1ms/step - loss: 19.5340 - mse: 19.5340 - val_loss: 4.1638 - val_mse: 4.1638
# Epoch 12/30
# 4743/4743 [==============================] - 5s 1ms/step - loss: 7.3622 - mse: 7.3622 - val_loss: 2.9991 - val_mse: 2.9991
# Epoch 13/30
# 4743/4743 [==============================] - 5s 1ms/step - loss: 7.1918 - mse: 7.1918 - val_loss: 2.0726 - val_mse: 2.0726
# Epoch 14/30
# 4743/4743 [==============================] - 5s 1ms/step - loss: 4.5165 - mse: 4.5165 - val_loss: 1.5213 - val_mse: 1.5213
# Epoch 15/30
# 4743/4743 [==============================] - 5s 1ms/step - loss: 4.3520 - mse: 4.3520 - val_loss: 1.5212 - val_mse: 1.5212
# Epoch 16/30
# 4743/4743 [==============================] - 5s 1ms/step - loss: 7.6093 - mse: 7.6093 - val_loss: 1.4654 - val_mse: 1.4654
# Epoch 17/30
# 4743/4743 [==============================] - 5s 1ms/step - loss: 4.1352 - mse: 4.1352 - val_loss: 1.5538 - val_mse: 1.5538
# Epoch 18/30
# 4743/4743 [==============================] - 5s 1ms/step - loss: 4.3225 - mse: 4.3225 - val_loss: 1.1890 - val_mse: 1.1890

# %%
rmse(model_1, X_valid)
pred_n_save(model_1, 'pred320_base_fs2_20cb.csv')
# Out:
# 1.0758626945695986

# %%
# Plot history: MAE
plt.plot(history1.history['loss'], label='MAE (training data)')
plt.plot(history1.history['val_loss'], label='MAE (validation data)')
plt.title('MAE for future sales prediction')
plt.ylabel('MAE value')
plt.xlabel('No. epoch')
plt.legend(loc="upper left")
plt.ylim([0, 100])
plt.show()

# %%
#Use the wider model

# %%
model_2 = wider_model()
model_2.summary()
history2 = model_2.fit(X_train, y_train, validation_data = (X_valid, y_valid), batch_size = 5000, epochs=30, callbacks = [earlystopping])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 40)                760
# _________________________________________________________________
# dense_4 (Dense)              (None, 60)                2460
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 61
# =================================================================
# Total params: 3,281
# Trainable params: 3,281
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 4743/4743 [==============================] - 14s 3ms/step - loss: 72740.9069 - mse: 72740.9069 - val_loss: 55.6499 - val_mse: 55.6499
# Epoch 2/30
# 4743/4743 [==============================] - 11s 2ms/step - loss: 475.1914 - mse: 475.1914 - val_loss: 19.4301 - val_mse: 19.4301
# Epoch 3/30
# 4743/4743 [==============================] - 12s 2ms/step - loss: 134.7720 - mse: 134.7720 - val_loss: 1.1816 - val_mse: 1.1816
# Epoch 4/30
# 4743/4743 [==============================] - 13s 3ms/step - loss: 82.5253 - mse: 82.5253 - val_loss: 2.4646 - val_mse: 2.4646
# Epoch 5/30
# 4743/4743 [==============================] - 14s 3ms/step - loss: 47.6687 - mse: 47.6687 - val_loss: 18.7954 - val_mse: 18.7954
# Epoch 6/30
# 4743/4743 [==============================] - 13s 3ms/step - loss: 21.1793 - mse: 21.1793 - val_loss: 1.7975 - val_mse: 1.7975
# Epoch 7/30
# 4743/4743 [==============================] - 13s 3ms/step - loss: 11.0551 - mse: 11.0551 - val_loss: 1.0614 - val_mse: 1.0614
# Epoch 8/30
# 4743/4743 [==============================] - 13s 3ms/step - loss: 6.3143 - mse: 6.3143 - val_loss: 1.3396 - val_mse: 1.3396
# Epoch 9/30
# 4743/4743 [==============================] - 13s 3ms/step - loss: 3.3066 - mse: 3.3066 - val_loss: 1.9310 - val_mse: 1.9310
# Epoch 10/30
# 4743/4743 [==============================] - 13s 3ms/step - loss: 4.3631 - mse: 4.3631 - val_loss: 1.9142 - val_mse: 1.9142
# Epoch 11/30
# 4743/4743 [==============================] - 14s 3ms/step - loss: 4.3324 - mse: 4.3324 - val_loss: 1.9134 - val_mse: 1.9134
# Epoch 12/30
# 4743/4743 [==============================] - 14s 3ms/step - loss: 3.9976 - mse: 3.9976 - val_loss: 1.9134 - val_mse: 1.9134
# Epoch 13/30
# 4743/4743 [==============================] - 13s 3ms/step - loss: 4.2987 - mse: 4.2987 - val_loss: 1.9138 - val_mse: 1.9138
# Epoch 14/30
# 4743/4743 [==============================] - 14s 3ms/step - loss: 4.7260 - mse: 4.7260 - val_loss: 1.9137 - val_mse: 1.9137
# Epoch 15/30
# 4743/4743 [==============================] - 13s 3ms/step - loss: 4.0314 - mse: 4.0314 - val_loss: 1.9133 - val_mse: 1.9133
# Epoch 16/30
# 4743/4743 [==============================] - 13s 3ms/step - loss: 4.4122 - mse: 4.4122 - val_loss: 1.9135 - val_mse: 1.9135
# Epoch 17/30
# 4743/4743 [==============================] - 13s 3ms/step - loss: 4.4770 - mse: 4.4770 - val_loss: 1.9134 - val_mse: 1.9134

# %%
rmse(model_2, X_valid)
pred_n_save(model_2, 'pred330_wider_fs2_20cb.csv')
# Out:
# 1.030242134209863

# %%
# Plot history: MAE
plt.plot(history2.history['loss'], label='MAE (training data)')
plt.plot(history2.history['val_loss'], label='MAE (validation data)')
plt.title('MAE for future sales prediction')
plt.ylabel('MAE value')
plt.xlabel('No. epoch')
plt.legend(loc="upper left")
plt.ylim([0, 100])
plt.show()

# %%
#Use the deeper model
model_3 = deeper_model()
model_3.summary()
history3 = model_3.fit(X_train, y_train, validation_data = (X_valid, y_valid), batch_size = 5000, epochs=30, callbacks = [earlystopping])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 40)                760
# _________________________________________________________________
# dense_7 (Dense)              (None, 60)                2460
# _________________________________________________________________
# dense_8 (Dense)              (None, 60)                3660
# _________________________________________________________________
# dense_9 (Dense)              (None, 12)                732
# _________________________________________________________________
# dropout (Dropout)            (None, 12)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 13
# =================================================================
# Total params: 7,625
# Trainable params: 7,625
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 4743/4743 [==============================] - 21s 4ms/step - loss: 54248.4435 - mse: 54248.4435 - val_loss: 1.9165 - val_mse: 1.9165
# Epoch 2/30
# 4743/4743 [==============================] - 23s 5ms/step - loss: 4.0025 - mse: 4.0025 - val_loss: 1.9146 - val_mse: 1.9146
# Epoch 3/30
# 4743/4743 [==============================] - 23s 5ms/step - loss: 4.0986 - mse: 4.0986 - val_loss: 1.9138 - val_mse: 1.9138
# Epoch 4/30
# 4743/4743 [==============================] - 23s 5ms/step - loss: 4.2794 - mse: 4.2794 - val_loss: 1.9135 - val_mse: 1.9135
# Epoch 5/30
# 4743/4743 [==============================] - 23s 5ms/step - loss: 4.2622 - mse: 4.2622 - val_loss: 1.9140 - val_mse: 1.9140
# Epoch 6/30
# 4743/4743 [==============================] - 23s 5ms/step - loss: 4.7875 - mse: 4.7875 - val_loss: 1.9139 - val_mse: 1.9139
# Epoch 7/30
# 4743/4743 [==============================] - 24s 5ms/step - loss: 4.4368 - mse: 4.4368 - val_loss: 1.9132 - val_mse: 1.9132
# Epoch 8/30
# 4743/4743 [==============================] - 23s 5ms/step - loss: 4.7689 - mse: 4.7689 - val_loss: 1.9135 - val_mse: 1.9135
# Epoch 9/30
# 4743/4743 [==============================] - 24s 5ms/step - loss: 4.5902 - mse: 4.5902 - val_loss: 1.9129 - val_mse: 1.9129
# Epoch 10/30
# 4743/4743 [==============================] - 23s 5ms/step - loss: 4.3943 - mse: 4.3943 - val_loss: 1.9133 - val_mse: 1.9133
# Epoch 11/30
# 4743/4743 [==============================] - 24s 5ms/step - loss: 4.0532 - mse: 4.0532 - val_loss: 1.9137 - val_mse: 1.9137
# Epoch 12/30
# 4743/4743 [==============================] - 24s 5ms/step - loss: 4.4060 - mse: 4.4060 - val_loss: 1.9131 - val_mse: 1.9131
# Epoch 13/30
# 4743/4743 [==============================] - 24s 5ms/step - loss: 4.4777 - mse: 4.4777 - val_loss: 1.9132 - val_mse: 1.9132
# Epoch 14/30
# 4743/4743 [==============================] - 22s 5ms/step - loss: 4.0539 - mse: 4.0539 - val_loss: 1.9132 - val_mse: 1.9132
# Epoch 15/30
# 4743/4743 [==============================] - 23s 5ms/step - loss: 4.3075 - mse: 4.3075 - val_loss: 1.9131 - val_mse: 1.9131
# Epoch 16/30
# 4743/4743 [==============================] - 25s 5ms/step - loss: 4.3433 - mse: 4.3433 - val_loss: 1.9132 - val_mse: 1.9132
# Epoch 17/30
# 4743/4743 [==============================] - 23s 5ms/step - loss: 4.2228 - mse: 4.2228 - val_loss: 1.9127 - val_mse: 1.9127
# Epoch 18/30
# 4743/4743 [==============================] - 24s 5ms/step - loss: 4.1266 - mse: 4.1266 - val_loss: 1.9136 - val_mse: 1.9136
# Epoch 19/30
# 4743/4743 [==============================] - 24s 5ms/step - loss: 4.4412 - mse: 4.4412 - val_loss: 1.9129 - val_mse: 1.9129
# Epoch 20/30
# 4743/4743 [==============================] - 24s 5ms/step - loss: 4.6833 - mse: 4.6833 - val_loss: 1.9138 - val_mse: 1.9138
# Epoch 21/30
# 4743/4743 [==============================] - 24s 5ms/step - loss: 4.4089 - mse: 4.4089 - val_loss: 1.9126 - val_mse: 1.9126
# Epoch 22/30
# 4743/4743 [==============================] - 24s 5ms/step - loss: 4.3683 - mse: 4.3683 - val_loss: 1.9140 - val_mse: 1.9140
# Epoch 23/30
# 4743/4743 [==============================] - 24s 5ms/step - loss: 4.6162 - mse: 4.6162 - val_loss: 1.9138 - val_mse: 1.9138
# Epoch 24/30
# 4743/4743 [==============================] - 24s 5ms/step - loss: 5.4093 - mse: 5.4093 - val_loss: 1.9141 - val_mse: 1.9141
# Epoch 25/30
# 4743/4743 [==============================] - 24s 5ms/step - loss: 4.3787 - mse: 4.3787 - val_loss: 1.9133 - val_mse: 1.9133
# Epoch 26/30
# 4743/4743 [==============================] - 24s 5ms/step - loss: 4.4393 - mse: 4.4393 - val_loss: 1.9140 - val_mse: 1.9140
# Epoch 27/30
# 4743/4743 [==============================] - 24s 5ms/step - loss: 4.3156 - mse: 4.3156 - val_loss: 1.9128 - val_mse: 1.9128
# Epoch 28/30
# 4743/4743 [==============================] - 24s 5ms/step - loss: 4.8773 - mse: 4.8773 - val_loss: 1.9134 - val_mse: 1.9134
# Epoch 29/30
# 4743/4743 [==============================] - 24s 5ms/step - loss: 4.9754 - mse: 4.9754 - val_loss: 1.9135 - val_mse: 1.9135
# Epoch 30/30
# 4743/4743 [==============================] - 24s 5ms/step - loss: 4.5520 - mse: 4.5520 - val_loss: 1.9134 - val_mse: 1.9134

# %%
rmse(model_3, X_valid)
pred_n_save(model_3, 'pred330_deeper_fs2_20cb.csv')
# Out:
# 1.3832465973678636

# %%
# Plot history: MAE
plt.plot(history3.history['loss'], label='MAE (training data)')
plt.plot(history3.history['val_loss'], label='MAE (validation data)')
plt.title('MAE for future sales prediction')
plt.ylabel('MAE value')
plt.xlabel('No. epoch')
plt.legend(loc="upper left")
plt.ylim([0, 100])
plt.show()

# %%
#Use base model train with X_train_pca(explained_variance_ratio = 90%)
model_4 = wider_model_pca()
model_4.summary()
history4 = model_4.fit(X_train_pca, y_train, validation_data = (X_valid_pca, y_valid), batch_size = 5000, epochs=30, callbacks = [earlystopping])
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_17 (Dense)             (None, 40)                680
# _________________________________________________________________
# dense_18 (Dense)             (None, 60)                2460
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 61
# =================================================================
# Total params: 3,201
# Trainable params: 3,201
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 4743/4743 [==============================] - 13s 2ms/step - loss: 3.8866 - mse: 3.8867 - val_loss: 1.0579 - val_mse: 1.0579
# Epoch 2/30
# 4743/4743 [==============================] - 12s 3ms/step - loss: 2.7415 - mse: 2.7415 - val_loss: 1.0265 - val_mse: 1.0265
# Epoch 3/30
# 4743/4743 [==============================] - 14s 3ms/step - loss: 2.5337 - mse: 2.5337 - val_loss: 0.9975 - val_mse: 0.9975
# Epoch 4/30
# 4743/4743 [==============================] - 14s 3ms/step - loss: 2.6661 - mse: 2.6661 - val_loss: 1.2278 - val_mse: 1.2278
# Epoch 5/30
# 4743/4743 [==============================] - 15s 3ms/step - loss: 2.6569 - mse: 2.6569 - val_loss: 1.0262 - val_mse: 1.0262
# Epoch 6/30
# 4743/4743 [==============================] - 14s 3ms/step - loss: 2.5427 - mse: 2.5427 - val_loss: 1.0854 - val_mse: 1.0854
# Epoch 7/30
# 4743/4743 [==============================] - 14s 3ms/step - loss: 2.2454 - mse: 2.2454 - val_loss: 1.1264 - val_mse: 1.1264
# Epoch 8/30
# 4743/4743 [==============================] - 14s 3ms/step - loss: 2.4912 - mse: 2.4912 - val_loss: 1.0859 - val_mse: 1.0859
# Epoch 9/30
# 4743/4743 [==============================] - 14s 3ms/step - loss: 2.0391 - mse: 2.0391 - val_loss: 1.0666 - val_mse: 1.0666
# Epoch 10/30
# 4743/4743 [==============================] - 14s 3ms/step - loss: 2.3708 - mse: 2.3708 - val_loss: 1.1587 - val_mse: 1.1587
# Epoch 11/30
# 4743/4743 [==============================] - 15s 3ms/step - loss: 2.4221 - mse: 2.4221 - val_loss: 1.1058 - val_mse: 1.1058
# Epoch 12/30
# 4743/4743 [==============================] - 14s 3ms/step - loss: 2.3563 - mse: 2.3563 - val_loss: 1.0953 - val_mse: 1.0953
# Epoch 13/30
# 4743/4743 [==============================] - 14s 3ms/step - loss: 2.2133 - mse: 2.2133 - val_loss: 1.2766 - val_mse: 1.2766

# %%
rmse(model_4, X_valid_pca)
# Out:
# 0.9987658394920993

# %%
#We choose the wider model and apply learning rate to optimize the training
from keras import optimizers
# create model
model = Sequential()
model.add(Dense(40, input_dim=X_train.shape[1], kernel_initializer='normal', activation='relu'))
model.add(Dense(60, activation='relu'))
model.add(Dense(1, activation='linear'))
# Compile model


opt = optimizers.Adam(learning_rate=0.0002)
model.compile(loss='mean_squared_error', optimizer=opt, metrics = 'mse')

# %%
model.summary()
earlystopping = callbacks.EarlyStopping(monitor ="val_loss", 
                                        mode ="auto", patience = 30, 
                                        restore_best_weights = True)

history = model.fit(X_train, y_train, validation_data = (X_valid, y_valid), batch_size = 5000, epochs=60, callbacks = [earlystopping])
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_38 (Dense)             (None, 40)                760
# _________________________________________________________________
# dense_39 (Dense)             (None, 60)                2460
# _________________________________________________________________
# dense_40 (Dense)             (None, 1)                 61
# =================================================================
# Total params: 3,281
# Trainable params: 3,281
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 4743/4743 [==============================] - 14s 3ms/step - loss: 341942.2670 - mse: 341942.3324 - val_loss: 5.3190 - val_mse: 5.3190
# Epoch 2/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 307.2772 - mse: 307.2772 - val_loss: 1.8367 - val_mse: 1.8367
# Epoch 3/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 20.4654 - mse: 20.4654 - val_loss: 63.8344 - val_mse: 63.8344
# Epoch 4/60
# 4743/4743 [==============================] - 12s 3ms/step - loss: 61.7252 - mse: 61.7252 - val_loss: 563.0982 - val_mse: 563.0982
# Epoch 5/60
# 4743/4743 [==============================] - 12s 3ms/step - loss: 50.5401 - mse: 50.5401 - val_loss: 25.2408 - val_mse: 25.2408
# Epoch 6/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 46.5176 - mse: 46.5176 - val_loss: 2.7042 - val_mse: 2.7042
# Epoch 7/60
# 4743/4743 [==============================] - 12s 3ms/step - loss: 31.2469 - mse: 31.2469 - val_loss: 91.9167 - val_mse: 91.9167
# Epoch 8/60
# 4743/4743 [==============================] - 12s 3ms/step - loss: 31.1068 - mse: 31.1068 - val_loss: 81.7813 - val_mse: 81.7813
# Epoch 9/60
# 4743/4743 [==============================] - 12s 3ms/step - loss: 32.4280 - mse: 32.4280 - val_loss: 4.2286 - val_mse: 4.2286
# Epoch 10/60
# 4743/4743 [==============================] - 12s 3ms/step - loss: 24.4436 - mse: 24.4436 - val_loss: 5.4569 - val_mse: 5.4569
# Epoch 11/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 23.2828 - mse: 23.2828 - val_loss: 31.4460 - val_mse: 31.4460
# Epoch 12/60
# 4743/4743 [==============================] - 12s 3ms/step - loss: 21.2955 - mse: 21.2955 - val_loss: 38.4430 - val_mse: 38.4430
# Epoch 13/60
# 4743/4743 [==============================] - 12s 3ms/step - loss: 37.3469 - mse: 37.3469 - val_loss: 3.1412 - val_mse: 3.1412
# Epoch 14/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 18.2152 - mse: 18.2152 - val_loss: 24.8749 - val_mse: 24.8749
# Epoch 15/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 47.2543 - mse: 47.2543 - val_loss: 1.2748 - val_mse: 1.2748
# Epoch 16/60
# 4743/4743 [==============================] - 12s 3ms/step - loss: 17.2205 - mse: 17.2205 - val_loss: 1.2416 - val_mse: 1.2416
# Epoch 17/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 12.4565 - mse: 12.4565 - val_loss: 1.3065 - val_mse: 1.3065
# Epoch 18/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 13.8526 - mse: 13.8526 - val_loss: 2.9495 - val_mse: 2.9495
# Epoch 19/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 12.9528 - mse: 12.9528 - val_loss: 1.7572 - val_mse: 1.7572
# Epoch 20/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 13.8004 - mse: 13.8004 - val_loss: 9.4989 - val_mse: 9.4989
# Epoch 21/60
# 4743/4743 [==============================] - 12s 3ms/step - loss: 11.3310 - mse: 11.3310 - val_loss: 1.3295 - val_mse: 1.3295
# Epoch 22/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 9.8203 - mse: 9.8203 - val_loss: 16.4602 - val_mse: 16.4602
# Epoch 23/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 10.0991 - mse: 10.0991 - val_loss: 2.6324 - val_mse: 2.6324
# Epoch 24/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 10.2560 - mse: 10.2560 - val_loss: 46.5029 - val_mse: 46.5029
# Epoch 25/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 9.1980 - mse: 9.1980 - val_loss: 1.4728 - val_mse: 1.4728
# Epoch 26/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 8.7768 - mse: 8.7768 - val_loss: 1.1978 - val_mse: 1.1978
# Epoch 27/60
# 4743/4743 [==============================] - 12s 3ms/step - loss: 11.0166 - mse: 11.0166 - val_loss: 1.5079 - val_mse: 1.5079
# Epoch 28/60
# 4743/4743 [==============================] - 12s 3ms/step - loss: 13.1670 - mse: 13.1670 - val_loss: 1.1464 - val_mse: 1.1464
# Epoch 29/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 5.0801 - mse: 5.0801 - val_loss: 1.2972 - val_mse: 1.2972
# Epoch 30/60
# 4743/4743 [==============================] - 12s 3ms/step - loss: 5.8415 - mse: 5.8415 - val_loss: 1.1501 - val_mse: 1.1501
# Epoch 31/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 8.5951 - mse: 8.5951 - val_loss: 1.2016 - val_mse: 1.2016
# Epoch 32/60
# 4743/4743 [==============================] - 12s 3ms/step - loss: 6.5558 - mse: 6.5558 - val_loss: 4.5010 - val_mse: 4.5010
# Epoch 33/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 7.8649 - mse: 7.8649 - val_loss: 1.8512 - val_mse: 1.8512
# Epoch 34/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 7.5307 - mse: 7.5307 - val_loss: 1.5609 - val_mse: 1.5609
# Epoch 35/60
# 4743/4743 [==============================] - 12s 3ms/step - loss: 5.4035 - mse: 5.4035 - val_loss: 3.8952 - val_mse: 3.8952
# Epoch 36/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 5.6232 - mse: 5.6232 - val_loss: 1.2086 - val_mse: 1.2086
# Epoch 37/60
# 4743/4743 [==============================] - 12s 3ms/step - loss: 4.8638 - mse: 4.8638 - val_loss: 1.3148 - val_mse: 1.3148
# Epoch 38/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 4.3549 - mse: 4.3549 - val_loss: 1.5171 - val_mse: 1.5171
# Epoch 39/60
# 4743/4743 [==============================] - 12s 3ms/step - loss: 5.8623 - mse: 5.8623 - val_loss: 1.4416 - val_mse: 1.4416
# Epoch 40/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 5.2689 - mse: 5.2689 - val_loss: 1.2531 - val_mse: 1.2531
# Epoch 41/60
# 4743/4743 [==============================] - 12s 3ms/step - loss: 5.0375 - mse: 5.0375 - val_loss: 2.2736 - val_mse: 2.2736
# Epoch 42/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 5.1927 - mse: 5.1927 - val_loss: 2.5837 - val_mse: 2.5837
# Epoch 43/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 4.5257 - mse: 4.5257 - val_loss: 1.1433 - val_mse: 1.1433
# Epoch 44/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 4.3824 - mse: 4.3824 - val_loss: 1.1184 - val_mse: 1.1184
# Epoch 45/60
# 4743/4743 [==============================] - 12s 3ms/step - loss: 3.8731 - mse: 3.8731 - val_loss: 1.3543 - val_mse: 1.3543
# Epoch 46/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 4.3195 - mse: 4.3195 - val_loss: 1.1451 - val_mse: 1.1451
# Epoch 47/60
# 4743/4743 [==============================] - 12s 3ms/step - loss: 3.4097 - mse: 3.4097 - val_loss: 1.1522 - val_mse: 1.1522
# Epoch 48/60
# 4743/4743 [==============================] - 12s 3ms/step - loss: 4.2808 - mse: 4.2808 - val_loss: 4.4712 - val_mse: 4.4712
# Epoch 49/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 5.2343 - mse: 5.2343 - val_loss: 1.4713 - val_mse: 1.4713
# Epoch 50/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 3.4040 - mse: 3.4040 - val_loss: 1.9280 - val_mse: 1.9280
# Epoch 51/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 4.0823 - mse: 4.0823 - val_loss: 1.7923 - val_mse: 1.7923
# Epoch 52/60
# 4743/4743 [==============================] - 14s 3ms/step - loss: 3.8585 - mse: 3.8585 - val_loss: 1.2382 - val_mse: 1.2382
# Epoch 53/60
# 4743/4743 [==============================] - 14s 3ms/step - loss: 3.6715 - mse: 3.6715 - val_loss: 1.8688 - val_mse: 1.8688
# Epoch 54/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 5.2511 - mse: 5.2511 - val_loss: 1.4059 - val_mse: 1.4059
# Epoch 55/60
# 4743/4743 [==============================] - 12s 3ms/step - loss: 3.7330 - mse: 3.7330 - val_loss: 1.2636 - val_mse: 1.2636
# Epoch 56/60
# 4743/4743 [==============================] - 12s 2ms/step - loss: 4.1432 - mse: 4.1432 - val_loss: 1.1199 - val_mse: 1.1199
# Epoch 57/60
# 4743/4743 [==============================] - 12s 3ms/step - loss: 3.4908 - mse: 3.4908 - val_loss: 1.1444 - val_mse: 1.1444
# Epoch 58/60
# 4743/4743 [==============================] - 12s 3ms/step - loss: 4.1667 - mse: 4.1667 - val_loss: 1.3172 - val_mse: 1.3172
# Epoch 59/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 3.1510 - mse: 3.1510 - val_loss: 1.2791 - val_mse: 1.2791
# Epoch 60/60
# 4743/4743 [==============================] - 13s 3ms/step - loss: 3.2826 - mse: 3.2826 - val_loss: 1.3240 - val_mse: 1.3240

# %%
rmse(model, X_valid)
# Out:
# 1.1506443493071878

# %%
# Plot history: MAE
plt.plot(history.history['loss'], label='MAE (training data)')
plt.plot(history.history['val_loss'], label='MAE (validation data)')
plt.title('MAE for future sales prediction')
plt.ylabel('MAE value')
plt.xlabel('No. epoch')
plt.legend(loc="upper left")
plt.ylim([0, 600])
plt.show()

# %%
pred_n_save(model_3, 'pred830_wider_fs2_30cb.csv')
