# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns
import re
from itertools import product

# %%
# !mkdir data 
# !mv *.csv data/
# Out:
# mkdir: cannot create directory ‘data’: File exists
# mv: cannot stat '*.csv': No such file or directory

# %%
train = pd.read_csv('data/sales_train.csv')
test = pd.read_csv('data/test.csv')
shops = pd.read_csv('data/shops.csv')
cats = pd.read_csv('data/item_categories.csv')
items = pd.read_csv('data/items.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# 1. Remove Outliers

# %%
plt.figure(figsize=(10,4))
plt.xlim(-100, 3000)
flierprops = dict(marker='o', markerfacecolor='purple', markersize=6,
                  linestyle='none', markeredgecolor='black')
sns.boxplot(x=train.item_cnt_day, flierprops=flierprops)

plt.figure(figsize=(10,4))
plt.xlim(train.item_price.min(), train.item_price.max()*1.1)
sns.boxplot(x=train.item_price, flierprops=flierprops)

# %%
train = train[(train.item_price < 300000 ) & (train.item_cnt_day < 1000)]

# %%
# remove negative price and sales count
train = train[train.item_price > 0].reset_index(drop = True)
train.loc[train.item_cnt_day < 1, "item_cnt_day"] = 0

# %% [markdown]
# 2. Cleaning Shop Data
#
# Several of the shops look like duplicates of each other. This could be down to shops re-opening or possibly moving store location on the same street or shopping centre.

# %%
# Якутск Орджоникидзе, 56
train.loc[train.shop_id == 0, 'shop_id'] = 57
test.loc[test.shop_id == 0, 'shop_id'] = 57
# Якутск ТЦ "Центральный"
train.loc[train.shop_id == 1, 'shop_id'] = 58
test.loc[test.shop_id == 1, 'shop_id'] = 58
# Жуковский ул. Чкалова 39м²
train.loc[train.shop_id == 10, 'shop_id'] = 11
test.loc[test.shop_id == 10, 'shop_id'] = 11

# %%
# Clean up some shop names and add 'city' and 'category' to shops df.

shops.loc[ shops.shop_name == 'Сергиев Посад ТЦ "7Я"',"shop_name" ] = 'СергиевПосад ТЦ "7Я"'
shops["city"] = shops.shop_name.str.split(" ").map( lambda x: x[0] )
shops["category"] = shops.shop_name.str.split(" ").map( lambda x: x[1] )
shops.loc[shops.city == "!Якутск", "city"] = "Якутск"
shops.head()
# Out:
#                         shop_name  shop_id      city       category
# 0   !Якутск Орджоникидзе, 56 фран        0    Якутск  Орджоникидзе,
# 1   !Якутск ТЦ "Центральный" фран        1    Якутск             ТЦ
# 2                Адыгея ТЦ "Мега"        2    Адыгея             ТЦ
# 3  Балашиха ТРК "Октябрь-Киномир"        3  Балашиха            ТРК
# 4        Волжский ТЦ "Волга Молл"        4  Волжский             ТЦ

# %%
# Only keep shop category if there are 5 or more shops of that category, the rest are grouped as "other".
category = []
for cat in shops.category.unique():
    if len(shops[shops.category == cat]) >= 5:
        category.append(cat)
shops.category = shops.category.apply( lambda x: x if (x in category) else "other" )

# %%
# encode shop category and city using labelencoder
shops["shop_category"] = LabelEncoder().fit_transform( shops.category )
shops["shop_city"] = LabelEncoder().fit_transform( shops.city )
shops = shops[["shop_id", "shop_category", "shop_city"]]
shops
# Out:
#     shop_id  shop_category  shop_city
# 0         0              0         29
# 1         1              4         29
# 2         2              4          0
# 3         3              2          1
# 4         4              4          2
# 5         5              3          3
# 6         6              0          4
# 7         7              3          4
# 8         8              3          4
# 9         9              0          5
# 10       10              0          6
# 11       11              0          6
# 12       12              0          7
# 13       13              4          8
# 14       14              4          8
# 15       15              3          9
# 16       16              4         10
# 17       17              4         11
# 18       18              4         11
# 19       19              4         12
# 20       20              0         13
# 21       21              0         13
# 22       22              0         13
# 23       23              1         13
# 24       24              1         13
# 25       25              2         13
# 26       26              4         13
# 27       27              4         13
# 28       28              4         13
# 29       29              4         13
# 30       30              4         13
# 31       31              4         13
# 32       32              4         13
# 33       33              2         14
# 34       34              3         15
# 35       35              3         15
# 36       36              3         16
# 37       37              4         16
# 38       38              4         17
# 39       39              2         18
# 40       40              2         18
# 41       41              4         18
# 42       42              1         19
# 43       43              1         19
# 44       44              4         20
# 45       45              4         20
# 46       46              4         21
# 47       47              3         22
# 48       48              3         23
# 49       49              3         24
# 50       50              4         24
# 51       51              4         24
# 52       52              1         25
# 53       53              4         25
# 54       54              4         26
# 55       55              0         27
# 56       56              3         28
# 57       57              0         29
# 58       58              4         29
# 59       59              4         30

# %% [markdown]
# 3. Cleaning Item Category Data

# %%
# split the category name and extract category type
cats["type_code"] = cats.item_category_name.apply( lambda x: x.split(" ")[0] ).astype(str)
cats.loc[ (cats.type_code == "Игровые")| (cats.type_code == "Аксессуары"), "category" ] = "Игры"
cats.head()
# Out:
#         item_category_name  item_category_id   type_code category
# 0  PC - Гарнитуры/Наушники                 0          PC      NaN
# 1         Аксессуары - PS2                 1  Аксессуары     Игры
# 2         Аксессуары - PS3                 2  Аксессуары     Игры
# 3         Аксессуары - PS4                 3  Аксессуары     Игры
# 4         Аксессуары - PSP                 4  Аксессуары     Игры

# %%
# If a category type has >=5 categories, make it a type otherwise make it etc
category = []
for cat in cats.type_code.unique():
    if len(cats[cats.type_code == cat]) >= 5: 
        category.append( cat )
cats.type_code = cats.type_code.apply(lambda x: x if (x in category) else "etc")
cats
# Out:
#            item_category_name  item_category_id   type_code category
# 0     PC - Гарнитуры/Наушники                 0         etc      NaN
# 1            Аксессуары - PS2                 1  Аксессуары     Игры
# 2            Аксессуары - PS3                 2  Аксессуары     Игры
# 3            Аксессуары - PS4                 3  Аксессуары     Игры
# 4            Аксессуары - PSP                 4  Аксессуары     Игры
# ..                        ...               ...         ...      ...
# 79                  Служебные                79         etc      NaN
# 80         Служебные - Билеты                80         etc      NaN
# 81    Чистые носители (шпиль)                81         etc      NaN
# 82  Чистые носители (штучные)                82         etc      NaN
# 83           Элементы питания                83         etc      NaN
#
# [84 rows x 4 columns]

# %%
# encode type_code using label encoder
cats.type_code = LabelEncoder().fit_transform(cats.type_code)

# extract subtype from category name and encode it
cats["split"] = cats.item_category_name.apply(lambda x: x.split("-"))
cats["subtype"] = cats.split.apply(lambda x: x[1].strip() if len(x) > 1 else x[0].strip())
cats["subtype_code"] = LabelEncoder().fit_transform( cats["subtype"] )
cats = cats[["item_category_id", "subtype_code", "type_code"]]
cats
# Out:
#     item_category_id  subtype_code  type_code
# 0                  0            29          0
# 1                  1             9          1
# 2                  2            10          1
# 3                  3            11          1
# 4                  4            13          1
# ..               ...           ...        ...
# 79                79            54          0
# 80                80            25          0
# 81                81            62          0
# 82                82            63          0
# 83                83            64          0
#
# [84 rows x 3 columns]

# %% [markdown]
# 4. Cleaning Item Data

# %%
def name_correction(x):
    x = x.lower() # all letters lower case
    x = x.partition('[')[0] # partition by square brackets
    x = x.partition('(')[0] # partition by curly brackets
    x = re.sub('[^A-Za-z0-9А-Яа-я]+', ' ', x) # remove special characters
    x = x.replace('  ', ' ') # replace double spaces with single spaces
    x = x.strip() # remove leading and trailing white space
    return x

# %%
# Clean item names.

# split item names by first bracket
items["name1"], items["name2"] = items.item_name.str.split("[", 1).str
items["name1"], items["name3"] = items.item_name.str.split("(", 1).str

# replace special characters and turn to lower case
items["name2"] = items.name2.str.replace('[^A-Za-z0-9А-Яа-я]+', " ").str.lower()
items["name3"] = items.name3.str.replace('[^A-Za-z0-9А-Яа-я]+', " ").str.lower()

# fill nulls with '0'
items = items.fillna('0')

items["item_name"] = items["item_name"].apply(lambda x: name_correction(x))

# return all characters except the last if name 2 is not "0" - remove the closing bracket
items.name2 = items.name2.apply( lambda x: x[:-1] if x !="0" else "0")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   """

# %%
items.head(20)
# Out:
#                                         item_name  ...     name3
# 0                            во власти наваждения  ...   пласт d
# 1   abbyy finereader 12 professional edition full  ...         0
# 2                                   в лучах славы  ...     unv d
# 3                                   голубая волна  ...    univ d
# 4                                         коробка  ...  стекло d
# 5                     новые американские граффити  ...     uni d
# 6                                 удар по воротам  ...     uni d
# 7                               удар по воротам 2  ...     uni d
# 8                               чай с муссолини d  ...         0
# 9                          шугарлэндский экспресс  ...     uni d
# 10                             за гранью смерти d  ...         0
# 11                                 линия смерти d  ...         0
# 12                  михей и джуманджи сука любовь  ...         0
# 13                                 спасая эмили d  ...         0
# 14                     чокнутый профессор магия d  ...         0
# 15                     адреналин один против всех  ...   регион
# 16                                монгол с бодров  ...   регион
# 17                           не оставляющий следа  ...   регион
# 18                       бомба для невесты 2dvd d  ...         0
# 19                       золотая коллекция м ф 72  ...         0
#
# [20 rows x 6 columns]

# %%
# Clean item type (type populated based on name2)

items["type"] = items.name2.apply(lambda x: x[0:8] if x.split(" ")[0] == "xbox" else x.split(" ")[0] )
items.loc[(items.type == "x360") | (items.type == "xbox360") | (items.type == "xbox 360") ,"type"] = "xbox 360"
items.loc[ items.type == "", "type"] = "mac"
items.type = items.type.apply( lambda x: x.replace(" ", "") )
items.loc[ (items.type == 'pc' )| (items.type == 'pс') | (items.type == "pc"), "type" ] = "pc"
items.loc[ items.type == 'рs3' , "type"] = "ps3"

items.head(20)
# Out:
#                                         item_name  item_id  ...     name3 type
# 0                            во власти наваждения        0  ...   пласт d    0
# 1   abbyy finereader 12 professional edition full        1  ...         0   pc
# 2                                   в лучах славы        2  ...     unv d    0
# 3                                   голубая волна        3  ...    univ d    0
# 4                                         коробка        4  ...  стекло d    0
# 5                     новые американские граффити        5  ...     uni d    0
# 6                                 удар по воротам        6  ...     uni d    0
# 7                               удар по воротам 2        7  ...     uni d    0
# 8                               чай с муссолини d        8  ...         0    0
# 9                          шугарлэндский экспресс        9  ...     uni d    0
# 10                             за гранью смерти d       10  ...         0    0
# 11                                 линия смерти d       11  ...         0    0
# 12                  михей и джуманджи сука любовь       12  ...         0    0
# 13                                 спасая эмили d       13  ...         0    0
# 14                     чокнутый профессор магия d       14  ...         0    0
# 15                     адреналин один против всех       15  ...   регион     0
# 16                                монгол с бодров       16  ...   регион     0
# 17                           не оставляющий следа       17  ...   регион     0
# 18                       бомба для невесты 2dvd d       18  ...         0    0
# 19                       золотая коллекция м ф 72       19  ...         0    0
#
# [20 rows x 7 columns]

# %%
# how many items in each item type
group_sum = items.groupby(["type"]).agg({"item_id": "count"})
group_sum = group_sum.reset_index()
group_sum
# Out:
#         type  item_id
# 0          0    17661
# 1        5c5        1
# 2        5c7        2
# 3        5f4        1
# 4        6dv        1
# 5        6jv        1
# 6        6l6        1
# 7    android        3
# 8        hm3        1
# 9        j72        4
# 10       kf6        1
# 11       kf7        1
# 12       kg4        1
# 13       mac       43
# 14        pc     2628
# 15        ps       79
# 16       ps2        2
# 17       ps3      611
# 18       ps4      174
# 19       psp      115
# 20       s3v        1
# 21       s4v        1
# 22   xbox360      466
# 23   xboxone      123
# 24      англ        1
# 25        рс       14
# 26   русская        1
# 27    только        9
# 28     цифро        1
# 29  цифровая      222

# %%
# if a type has less than 40 items, make them into one single type called other
drop_cols = []
for cat in group_sum.type.unique():
    if group_sum.loc[(group_sum.type == cat), "item_id"].values[0] <40:
        drop_cols.append(cat)

items.name2 = items.name2.apply( lambda x: "other" if (x in drop_cols) else x )
items = items.drop(["type"], axis = 1)

# %%
# encode name2 and name3 
items.name2 = LabelEncoder().fit_transform(items.name2)
items.name3 = LabelEncoder().fit_transform(items.name3)

items.drop(["item_name", "name1"],axis = 1, inplace= True)
items.head()
# Out:
#    item_id  item_category_id  name2  name3
# 0        0                40      4   1331
# 1        1                76     64     42
# 2        2                40      4   1011
# 3        3                40      4   1010
# 4        4                40      4   1572

# %% [markdown]
# # Preprocessing

# %%
train.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00           0.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
# Create a matrix df with every combination of month, shop and item in order of increasing month. Item_cnt_day is summed into an item_cnt_month.

matrix = []
cols  = ["date_block_num", "shop_id", "item_id"]
for i in range(34):
    sales = train[train.date_block_num == i]
    matrix.append( np.array(list( product( [i], sales.shop_id.unique(), sales.item_id.unique() ) ), dtype = np.int16) )

matrix = pd.DataFrame( np.vstack(matrix), columns = cols )
matrix["date_block_num"] = matrix["date_block_num"].astype(np.int8)
matrix["shop_id"] = matrix["shop_id"].astype(np.int8)
matrix["item_id"] = matrix["item_id"].astype(np.int16)
matrix.sort_values( cols, inplace = True )

# %%
# add revenue to train df
train["revenue"] = train["item_cnt_day"] * train["item_price"]

# %%
train
# Out:
#                date  date_block_num  shop_id  ...  item_price  item_cnt_day  revenue
# 0        02.01.2013               0       59  ...      999.00           1.0   999.00
# 1        03.01.2013               0       25  ...      899.00           1.0   899.00
# 2        05.01.2013               0       25  ...      899.00           0.0     0.00
# 3        06.01.2013               0       25  ...     1709.05           1.0  1709.05
# 4        15.01.2013               0       25  ...     1099.00           1.0  1099.00
# ...             ...             ...      ...  ...         ...           ...      ...
# 2935840  10.10.2015              33       25  ...      299.00           1.0   299.00
# 2935841  09.10.2015              33       25  ...      299.00           1.0   299.00
# 2935842  14.10.2015              33       25  ...      349.00           1.0   349.00
# 2935843  22.10.2015              33       25  ...      299.00           1.0   299.00
# 2935844  03.10.2015              33       25  ...      299.00           1.0   299.00
#
# [2935845 rows x 7 columns]

# %%
# get monthly item count
group = train.groupby( ["date_block_num", "shop_id", "item_id"] ).agg( {"item_cnt_day": ["sum"]} )
group.columns = ["item_cnt_month"]
group.reset_index( inplace = True)
group
# Out:
#          date_block_num  shop_id  item_id  item_cnt_month
# 0                     0        2       27             1.0
# 1                     0        2       33             1.0
# 2                     0        2      317             1.0
# 3                     0        2      438             1.0
# 4                     0        2      471             2.0
# ...                 ...      ...      ...             ...
# 1609117              33       59    22087             6.0
# 1609118              33       59    22088             2.0
# 1609119              33       59    22091             1.0
# 1609120              33       59    22100             1.0
# 1609121              33       59    22102             1.0
#
# [1609122 rows x 4 columns]

# %%
# add monthly item count to matrix
matrix = pd.merge( matrix, group, on = cols, how = "left" )
matrix["item_cnt_month"] = matrix["item_cnt_month"].fillna(0).astype(np.float16)
matrix
# Out:
#           date_block_num  shop_id  item_id  item_cnt_month
# 0                      0        2       19             0.0
# 1                      0        2       27             1.0
# 2                      0        2       28             0.0
# 3                      0        2       29             0.0
# 4                      0        2       32             0.0
# ...                  ...      ...      ...             ...
# 10913799              33       59    22162             0.0
# 10913800              33       59    22163             0.0
# 10913801              33       59    22164             0.0
# 10913802              33       59    22166             0.0
# 10913803              33       59    22167             0.0
#
# [10913804 rows x 4 columns]

# %%
# Create a test set for month 34.
test
# Out:
#             ID  shop_id  item_id
# 0            0        5     5037
# 1            1        5     5320
# 2            2        5     5233
# 3            3        5     5232
# 4            4        5     5268
# ...        ...      ...      ...
# 214195  214195       45    18454
# 214196  214196       45    16188
# 214197  214197       45    15757
# 214198  214198       45    19648
# 214199  214199       45      969
#
# [214200 rows x 3 columns]

# %%
test["date_block_num"] = 34
test["date_block_num"] = test["date_block_num"].astype(np.int8)
test["shop_id"] = test.shop_id.astype(np.int8)
test["item_id"] = test.item_id.astype(np.int16)

# %%
# Concatenate train and test sets
matrix = pd.concat([matrix, test.drop(["ID"],axis = 1)], ignore_index=True, sort=False, keys=cols)
matrix.fillna( 0, inplace = True )
matrix
# Out:
#           date_block_num  shop_id  item_id  item_cnt_month
# 0                      0        2       19             0.0
# 1                      0        2       27             1.0
# 2                      0        2       28             0.0
# 3                      0        2       29             0.0
# 4                      0        2       32             0.0
# ...                  ...      ...      ...             ...
# 11127999              34       45    18454             0.0
# 11128000              34       45    16188             0.0
# 11128001              34       45    15757             0.0
# 11128002              34       45    19648             0.0
# 11128003              34       45      969             0.0
#
# [11128004 rows x 4 columns]

# %%
# Add shop, items and categories data onto matrix df.
matrix = pd.merge( matrix, shops, on = ["shop_id"], how = "left" )
matrix = pd.merge(matrix, items, on = ["item_id"], how = "left")
matrix = pd.merge( matrix, cats, on = ["item_category_id"], how = "left" )
matrix["shop_city"] = matrix["shop_city"].astype(np.int8)
matrix["shop_category"] = matrix["shop_category"].astype(np.int8)
matrix["item_category_id"] = matrix["item_category_id"].astype(np.int8)
matrix["subtype_code"] = matrix["subtype_code"].astype(np.int8)
matrix["name2"] = matrix["name2"].astype(np.int8)
matrix["name3"] = matrix["name3"].astype(np.int16)
matrix["type_code"] = matrix["type_code"].astype(np.int8)
matrix
# Out:
#           date_block_num  shop_id  item_id  ...  name3  subtype_code  type_code
# 0                      0        2       19  ...     42             4          5
# 1                      0        2       27  ...     42            10          3
# 2                      0        2       28  ...     42            55          3
# 3                      0        2       29  ...     42            16          3
# 4                      0        2       32  ...     42             4          5
# ...                  ...      ...      ...  ...    ...           ...        ...
# 11127999              34       45    18454  ...     42             2          7
# 11128000              34       45    16188  ...     42            42          8
# 11128001              34       45    15757  ...     42             2          7
# 11128002              34       45    19648  ...   1367             4          5
# 11128003              34       45      969  ...    562             1          5
#
# [11128004 rows x 11 columns]

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# Add additional features related to item count

# %%
def add_feature(df, group_by, col, col_name):
  group = df.groupby( group_by ).agg({col : ["mean"]})
  group.columns = [col_name]
  group.reset_index(inplace = True)
  df = pd.merge(df, group, on = group_by, how = "left")
  df[col_name] = df[col_name].astype(np.float16)
  return df

# %%
# average item count per month-shop-item_cat 
matrix = add_feature(matrix, ['date_block_num', 'shop_id', 'item_category_id'], "item_cnt_month", "month_shop_itemcat_avg_cnt")

# %%
# average item count per month-shop-item_type
matrix = add_feature(matrix, ['date_block_num', 'shop_id', 'type_code'], "item_cnt_month", "month_shop_itemtype_avg_cnt")

# %%
# average item count per month-shop_cat-item 
matrix = add_feature(matrix, ['date_block_num', 'shop_category', 'item_id'], "item_cnt_month", "month_shopcat_item_avg_cnt")

# %%
# average item count per month-shop_cat-item_cat 
matrix = add_feature(matrix, ['date_block_num', 'shop_category', 'item_category_id'], "item_cnt_month", "month_shopcat_itemcat_avg_cnt")

# %%
# average item count per month-city-item
matrix = add_feature(matrix, ['date_block_num', 'shop_city', 'item_id'], "item_cnt_month", "month_city_item_avg_cnt")

# %%
# average item count per month-city-item_cat
matrix = add_feature(matrix, ['date_block_num', 'shop_city', 'item_category_id'], "item_cnt_month", "month_city_itemcat_avg_cnt")

# %%
# average item count per month-shop
matrix = add_feature(matrix, ['date_block_num', 'shop_id'], "item_cnt_month", "month_shop_avg_cnt")

# %%
# average item count per month-shop_cat
matrix = add_feature(matrix, ['date_block_num', 'shop_category'], "item_cnt_month", "month_shopcat_avg_cnt")

# %%
# average item count per month-item
matrix = add_feature(matrix, ['date_block_num', 'item_id'], "item_cnt_month", "month_item_avg_cnt")

# %%
# average item count per month-item_cat
matrix = add_feature(matrix, ['date_block_num', 'item_category_id'], "item_cnt_month", "month_itemcat_avg_cnt")

# %%
# average item count per month-city
matrix = add_feature(matrix, ['date_block_num', 'shop_city'], "item_cnt_month", "month_city_avg_cnt")

# %%
# average item count per month
matrix = add_feature(matrix, ['date_block_num'], "item_cnt_month", "month_avg_cnt")

# %%
# average item count per item
matrix = add_feature(matrix, ['item_id'], "item_cnt_month", "item_avg_cnt")

# %%
# average item count per shop
matrix = add_feature(matrix, ['shop_id'], "item_cnt_month", "shop_avg_cnt")

# %% [markdown]
# Add additional features related to date to capture cycle and seasonality

# %%
# month
matrix['month'] = matrix['date_block_num']%12
matrix
# Out:
#           date_block_num  shop_id  item_id  ...  item_avg_cnt  shop_avg_cnt  month
# 0                      0        2       19  ...      0.022217      0.128418      0
# 1                      0        2       27  ...      0.056824      0.128418      0
# 2                      0        2       28  ...      0.142822      0.128418      0
# 3                      0        2       29  ...      0.040497      0.128418      0
# 4                      0        2       32  ...      1.286133      0.128418      0
# ...                  ...      ...      ...  ...           ...           ...    ...
# 11127999              34       45    18454  ...      0.955566      0.175781     10
# 11128000              34       45    16188  ...      0.031006      0.175781     10
# 11128001              34       45    15757  ...      0.227905      0.175781     10
# 11128002              34       45    19648  ...      0.103516      0.175781     10
# 11128003              34       45      969  ...      0.360596      0.175781     10
#
# [11128004 rows x 26 columns]

# %%
# year
import math
matrix['year'] = matrix['date_block_num']/12
matrix['year'] = matrix.year.apply(lambda x: math.floor(x))
matrix
# Out:
#           date_block_num  shop_id  item_id  ...  shop_avg_cnt  month  year
# 0                      0        2       19  ...      0.128418      0     0
# 1                      0        2       27  ...      0.128418      0     0
# 2                      0        2       28  ...      0.128418      0     0
# 3                      0        2       29  ...      0.128418      0     0
# 4                      0        2       32  ...      0.128418      0     0
# ...                  ...      ...      ...  ...           ...    ...   ...
# 11127999              34       45    18454  ...      0.175781     10     2
# 11128000              34       45    16188  ...      0.175781     10     2
# 11128001              34       45    15757  ...      0.175781     10     2
# 11128002              34       45    19648  ...      0.175781     10     2
# 11128003              34       45      969  ...      0.175781     10     2
#
# [11128004 rows x 27 columns]

# %%
# season 
season = pd.Series([0,0,0,1,1,1,2,2,2,3,3,3])
matrix["season"] = matrix["month"].map(season).astype(np.int8)

# %%
# number of days in the month
days = pd.Series([31,28,31,30,31,30,31,31,30,31,30,31])
matrix["days"] = matrix["month"].map(days).astype(np.int8)

# %% [markdown]
# Add additional features related to price

# %%
# avg price per month-item
group = train.groupby( ['date_block_num', 'item_id'] ).agg({"item_price" : ["mean"]})
group.columns = ["month_avg_item_price"]
group.reset_index(inplace = True)
matrix = pd.merge(matrix, group, on = ['date_block_num', 'item_id'], how = "left")
matrix
# Out:
#           date_block_num  shop_id  item_id  ...  season  days  month_avg_item_price
# 0                      0        2       19  ...       0    31             28.000000
# 1                      0        2       27  ...       0    31           2325.000000
# 2                      0        2       28  ...       0    31            549.000000
# 3                      0        2       29  ...       0    31           2397.500000
# 4                      0        2       32  ...       0    31            338.110349
# ...                  ...      ...      ...  ...     ...   ...                   ...
# 11127999              34       45    18454  ...       3    30                   NaN
# 11128000              34       45    16188  ...       3    30                   NaN
# 11128001              34       45    15757  ...       3    30                   NaN
# 11128002              34       45    19648  ...       3    30                   NaN
# 11128003              34       45      969  ...       3    30                   NaN
#
# [11128004 rows x 30 columns]

# %%
# avg price per year-item
year_price = train[['date', 'item_id','item_price']]
year_price['year'] = year_price.apply(lambda row: int(row.date.split('.')[2])-2013, axis = 1)
year_price
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                date  item_id  item_price  year
# 0        02.01.2013    22154      999.00     0
# 1        03.01.2013     2552      899.00     0
# 2        05.01.2013     2552      899.00     0
# 3        06.01.2013     2554     1709.05     0
# 4        15.01.2013     2555     1099.00     0
# ...             ...      ...         ...   ...
# 2935840  10.10.2015     7409      299.00     2
# 2935841  09.10.2015     7460      299.00     2
# 2935842  14.10.2015     7459      349.00     2
# 2935843  22.10.2015     7440      299.00     2
# 2935844  03.10.2015     7460      299.00     2
#
# [2935845 rows x 4 columns]

# %%
group = year_price.groupby( ['year', 'item_id'] ).agg({"item_price" : ["mean"]})
group.columns = ["year_avg_item_price"]
group.reset_index(inplace = True)
matrix = pd.merge(matrix, group, on = ['year', 'item_id'], how = "left")
matrix["year_avg_item_price"] = matrix['year_avg_item_price'].astype(np.float16)
matrix
# Out:
#           date_block_num  shop_id  ...  month_avg_item_price  year_avg_item_price
# 0                      0        2  ...             28.000000              28.0000
# 1                      0        2  ...           2325.000000            1594.0000
# 2                      0        2  ...            549.000000             311.2500
# 3                      0        2  ...           2397.500000            1802.0000
# 4                      0        2  ...            338.110349             308.0000
# ...                  ...      ...  ...                   ...                  ...
# 11127999              34       45  ...                   NaN             186.5000
# 11128000              34       45  ...                   NaN            1257.0000
# 11128001              34       45  ...                   NaN             206.8750
# 11128002              34       45  ...                   NaN              97.9375
# 11128003              34       45  ...                   NaN             309.7500
#
# [11128004 rows x 31 columns]

# %%
year_cat_price = pd.merge(year_price,items[['item_id','item_category_id']], on = 'item_id', how = 'left')

# %%
year_cat_price = year_cat_price[['item_price', 'year', 'item_category_id']].groupby( ['year', 'item_category_id'] ).agg({"item_price" : ["mean"]})
year_cat_price.columns = year_cat_price.columns.droplevel()
year_cat_price = year_cat_price.reset_index()
year_cat_price.columns = ['year', 'item_category_id', 'year_avg_cat_price']

# %%
year_cat_price
# Out:
#      year  item_category_id  year_avg_cat_price
# 0       0                 0           87.800000
# 1       0                 1          215.500000
# 2       0                 2         2149.426051
# 3       0                 3         1258.355488
# 4       0                 4          622.788241
# ..    ...               ...                 ...
# 211     2                79         1186.339569
# 212     2                80         1246.064128
# 213     2                81          350.000000
# 214     2                82           13.000000
# 215     2                83          130.470459
#
# [216 rows x 3 columns]

# %%
matrix = pd.merge(matrix, year_cat_price, on = ['year','item_category_id'], how = 'left')

# %%
# avg item price
group = train.groupby( ["item_id"] ).agg({"item_price": ["mean"]})
group.columns = ["item_avg_item_price"]
group.reset_index(inplace = True)
matrix = pd.merge( matrix,group, on = ["item_id"], how = "left" )
matrix["item_avg_item_price"] = matrix['item_avg_item_price'].astype(np.float16)

# %% [markdown]
# Delta features

# %%
#Lag features for change in price values
def lag_feature( df,lags, cols ):
    for col in cols:
        print(col)
        tmp = df[["date_block_num", "shop_id","item_id",col ]]
        for i in lags:
            shifted = tmp.copy()
            shifted.columns = ["date_block_num", "shop_id", "item_id", col + "_lag_"+str(i)]
            shifted.date_block_num = shifted.date_block_num + i
            df = pd.merge(df, shifted, on=['date_block_num','shop_id','item_id'], how='left')
    return df

# %%
lags = [1, 2, 3]
matrix = lag_feature( matrix, lags, ["month_avg_item_price"] )
# Out:
# month_avg_item_price

# %%
for i in lags:
    matrix["delta_price_lag_" + str(i) ] = (matrix["month_avg_item_price_lag_" + str(i)]- matrix["item_avg_item_price"] )/ matrix["item_avg_item_price"]

# %%
matrix
# Out:
#           date_block_num  shop_id  ...  delta_price_lag_2  delta_price_lag_3
# 0                      0        2  ...                NaN                NaN
# 1                      0        2  ...                NaN                NaN
# 2                      0        2  ...                NaN                NaN
# 3                      0        2  ...                NaN                NaN
# 4                      0        2  ...                NaN                NaN
# ...                  ...      ...  ...                ...                ...
# 11127999              34       45  ...          -0.475149          -0.475149
# 11128000              34       45  ...          -0.027075                NaN
# 11128001              34       45  ...           0.155836           0.155836
# 11128002              34       45  ...           0.008917          -0.033303
# 11128003              34       45  ...          -0.605774          -0.605774
#
# [11128004 rows x 39 columns]

# %%
#Function to select just one change in price compared to the rest 3
def select_trends(row) :
    for i in lags:
        if row["delta_price_lag_" + str(i)]:
            return row["delta_price_lag_" + str(i)]
    return 0

# %%
matrix["delta_price_lag"] = matrix.apply(select_trends, axis = 1)
matrix["delta_price_lag"] = matrix['delta_price_lag'].astype( np.float16 )
matrix["delta_price_lag"].fillna( 0 ,inplace = True)

# %%
#Drop unwanted features 
features_to_drop = ["item_avg_item_price", "month_avg_item_price"]
for i in lags:
    features_to_drop.append("month_avg_item_price_lag_" + str(i) )
    features_to_drop.append("delta_price_lag_" + str(i) )
matrix.drop(features_to_drop, axis = 1, inplace = True)

# %%
matrix
# Out:
#           date_block_num  shop_id  ...  year_avg_cat_price  delta_price_lag
# 0                      0        2  ...          248.578945         0.000000
# 1                      0        2  ...         1514.601304         0.000000
# 2                      0        2  ...          456.299900         0.000000
# 3                      0        2  ...         1543.248943         0.000000
# 4                      0        2  ...          248.578945         0.000000
# ...                  ...      ...  ...                 ...              ...
# 11127999              34       45  ...          309.341769        -0.475098
# 11128000              34       45  ...         1129.095644         0.081116
# 11128001              34       45  ...          309.341769         0.155884
# 11128002              34       45  ...          271.537594        -0.091980
# 11128003              34       45  ...          451.071719        -0.605957
#
# [11128004 rows x 32 columns]

# %% [markdown]
# Other features trend, first sales, last sell shops,…

# %%
#Revenue for shops based on date
group = train.groupby( ["date_block_num","shop_id"] ).agg({"revenue": ["sum"] })
group.columns = ["date_shop_revenue"]
group.reset_index(inplace = True)
matrix = matrix.merge( group , on = ["date_block_num", "shop_id"], how = "left" )
matrix['date_shop_revenue'] = matrix['date_shop_revenue'].astype(np.float32)

# %%
# Shop avg revenue
group = group.groupby(["shop_id"]).agg({ "date_block_num":["mean"] })
group.columns = ["shop_avg_revenue"]
group.reset_index(inplace = True )
matrix = matrix.merge( group, on = ["shop_id"], how = "left" )
matrix["shop_avg_revenue"] = matrix.shop_avg_revenue.astype(np.float32)

# %%
#Change in revenue - how current month revenue changes to global average
matrix["delta_revenue"] = (matrix['date_shop_revenue'] - matrix['shop_avg_revenue']) / matrix['shop_avg_revenue']
matrix["delta_revenue"] = matrix["delta_revenue"]. astype(np.float32)

# %%
matrix = lag_feature(matrix, [1], ["delta_revenue"])
matrix["delta_revenue_lag_1"] = matrix["delta_revenue_lag_1"].astype(np.float32)
# Out:
# delta_revenue

# %%
#Remove unwanted features after calculating the delta 
matrix.drop( ["date_shop_revenue", "shop_avg_revenue", "delta_revenue"] ,axis = 1, inplace = True)

# %%
#Item first sold in shop
matrix["item_shop_first_sale"] = matrix["date_block_num"] - matrix.groupby(["item_id","shop_id"])["date_block_num"].transform('min')
#Item first sold globally
matrix["item_first_sale"] = matrix["date_block_num"] - matrix.groupby(["item_id"])["date_block_num"].transform('min')

# %%
#Removing first 3 months as they dont have any lag values
matrix = matrix[matrix["date_block_num"] > 3]

# %%
#matrix.to_csv('matrix_04.csv')
matrix
# Out:
#           date_block_num  shop_id  ...  item_shop_first_sale  item_first_sale
# 1497465                4        2  ...                     4                4
# 1497466                4        2  ...                     4                4
# 1497467                4        2  ...                     4                4
# 1497468                4        2  ...                     3                3
# 1497469                4        2  ...                     3                3
# ...                  ...      ...  ...                   ...              ...
# 11127999              34       45  ...                    11               11
# 11128000              34       45  ...                     2                2
# 11128001              34       45  ...                    34               34
# 11128002              34       45  ...                    11               11
# 11128003              34       45  ...                    17               17
#
# [9630539 rows x 35 columns]

# %% [markdown]
# Adding the number of Russian holidays per month as a feature

# %%
holidays_per_month = [7, 1, 2, 1, 6, 2, 0, 0, 0, 0, 1, 1]
test_holidays = matrix.copy()

# %%
test_holidays["holidays_in_month"] = 0
dates = [x for x in range(4, 34)]

for i in range(0, 12):
  test_holidays['holidays_in_month'] = np.where(test_holidays['date_block_num']%12 == i, holidays_per_month[i], test_holidays['holidays_in_month'])
matrix = test_holidays
del test_holidays
matrix
# Out:
#           date_block_num  shop_id  ...  item_first_sale  holidays_in_month
# 1497465                4        2  ...                4                  6
# 1497466                4        2  ...                4                  6
# 1497467                4        2  ...                4                  6
# 1497468                4        2  ...                3                  6
# 1497469                4        2  ...                3                  6
# ...                  ...      ...  ...              ...                ...
# 11127999              34       45  ...               11                  1
# 11128000              34       45  ...                2                  1
# 11128001              34       45  ...               34                  1
# 11128002              34       45  ...               11                  1
# 11128003              34       45  ...               17                  1
#
# [9630539 rows x 36 columns]

# %%
data = matrix.copy()

# %%
# Create the training, validation, and testing datasets
drop_cols = ['item_cnt_month', 'month', 'year', 'season', 'item_first_sale']
x_train = data[data.date_block_num <= 33].drop(drop_cols, axis=1)
y_train = data[data.date_block_num <= 33]['item_cnt_month']
x_val = data[data.date_block_num == 33].drop(drop_cols, axis=1)
y_val = data[data.date_block_num == 33]['item_cnt_month']
x_test = data[data.date_block_num == 34].drop(drop_cols, axis=1)

# %%
# Delete the temporary data DataFrame
del data, train, test, shops, cats, items, group

# %%
import gc
gc.collect()
# Out:
# 200

# %%
! git clone --recursive https://github.com/Microsoft/LightGBM
! cd LightGBM && rm -rf build && mkdir build && cd build && cmake -DUSE_GPU=1 ../../LightGBM && make -j4 && cd ../python-package && python3 setup.py install --precompile --gpu;
import lightgbm as lgb

# %%
for col in x_train:
  x_train[col] = x_train[col].fillna(0)

for col in x_val:
  x_val[col] = x_val[col].fillna(0)

for col in x_test:
  x_test[col] = x_test[col].fillna(0)

# %%
train_data = lgb.Dataset(x_train.values, label=y_train.values.astype("float32"))

# %%
validation_data = lgb.Dataset(x_val.values, label=y_val.values, reference=train_data)

# %%
params = {'task':'train',
          'boosting_type':'gbdt',
          'objective':'regression',
          'metric':['l2', 'rmse'],
          'metric_freq':1,
          'is_training_metric':True,
          'max_bin':255,
          'num_trees':10000,
          'learning_rate':0.005,
          'num_leaves':200,
          'bagging_freq':5,
          'min_data_in_leaf':100,
          'min_sum_hessian_in_leaf':5.0,
          'device':'gpu',
          'max_depth': 200,
          'min_gain_to_split':0.2,
          'zero_as_missing':True
          }

# %%
evals = {}
res = lgb.train(params=params, train_set=train_data, valid_sets=[validation_data], early_stopping_rounds=50, verbose_eval=True, evals_result=evals)

# %%
predictions = res.predict(x_test, num_iteration=res.best_iteration, predict_disable_shape_check=True)

# %%
predictions = predictions.clip(0, 20)
test = pd.read_csv('data/test.csv')
submission = pd.DataFrame({
    'ID':test.index,
    'item_cnt_month':predictions
})

# %%
submission.to_csv('submission.csv', index=False)

# %%
from google.colab import files
files.download('submission.csv')

# %%
res.feature_importance()
# Out:
# array([ 11970,  46599,  14332,  26036,  14433,  10159,   4598,   4539,
#          8927,   6651, 187387,  39643, 127181,  40273, 155072, 146301,
#         67913,  23392,  48280,  25848,  76499,   5230,  11127, 116920,
#           109,  27603,  24080,  16810,  27626,  15104,   1862],
#       dtype=int32)

# %%
fig, ax = plt.subplots(figsize=(15, 10))
lgb.plot_importance(res, ax=ax)

# %%
ax1 = lgb.plot_metric(evals, metric='l2', title="L2 RMSE during training", figsize=(15, 10))
ax2 = lgb.plot_metric(evals, ax=ax1, metric='rmse', title="Validation RMSE", figsize=(15, 10))
ax2.legend(['L2', 'RMSE'], )
print()
